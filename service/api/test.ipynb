# %%
import pandas as pd
import numpy as np
import mosmapapi as mma

# %%
mma.api_call_analytic(54.3245, 37.3562, 300)
# Out:
# {'latitude': 54.3245,
#  'longitude': 37.3562,
#  'orgs': {'2': {'group_name': 'Медицина', 'count': 0},
#   '3': {'group_name': 'Стоматологии', 'count': 0},
#   '4': {'group_name': 'Аптеки, оптики', 'count': 0},
#   '5': {'group_name': 'Салоны красоты', 'count': 0},
#   '6': {'group_name': 'Бани, сауны', 'count': 0},
#   '7': {'group_name': 'Фитнес-центры, тренажерные', 'count': 0},
#   '8': {'group_name': 'Супермаркеты', 'count': 0},
#   '9': {'group_name': 'Гипермаркеты', 'count': 0},
#   '10': {'group_name': 'Продуктовые магазины', 'count': 0},
#   '11': {'group_name': 'Алкомаркеты, магазины пива', 'count': 0},
#   '13': {'group_name': 'Школы, лицеи, гимназии', 'count': 0},
#   '14': {'group_name': 'Детские сады', 'count': 0},
#   '15': {'group_name': 'Колледжи, институты', 'count': 0},
#   '16': {'group_name': 'Студенческие общежития', 'count': 0},
#   '17': {'group_name': 'Торговые центры, моллы', 'count': 0},
#   '18': {'group_name': 'Бизнес-центры', 'count': 0},
# ...

# %%
await mma.get_all_data(54.3245, 1000000000)
# Out:
#    district_name  n_buildings_300m  n_living_buildings_300m  n_flats_300m  \
# 0            NaN               NaN                      NaN           NaN
#
#   min_bc_distance_300m mean_bc_distance_300m  traffic1_300m  traffic2_300m  \
# 0                 None                  None              0              0
#
#    traffic3_300m  traffic4_300m  ...  Ветаптеки и ветклиники_600  \
# 0              0              0  ...                           0
#
#    Магазины цветов_600  Прачечные, химчистки_600  Детские игровые залы_600  \
# 0                    0                         0                         0
#
#    Религия_600  Пиццерии, суши, столовые_600  Пекарни, кофейни_600  \
# 0            0                             0                     0
#
#    Кафе, бары, рестораны_600  Социальные_600  Банки_600
# 0                          0               0          0
#
# [1 rows x 74 columns]
