# %%
from schemas import AdvertInput

input_dict = {
    'Тип автора': 'Агентство',
    'Метро/Район': 'Шипиловская',
    'lat': 55.6212,
    'lng': 37.7456,
    'Расстояние до метро, км': 0.083,
    'Этаж': None,
    'Вид объекта': 'Офисное помещение',
    'Общая площадь': 25.0
}

AdvertInput(**input_dict).model_dump()
# Out:
# {'lat': 55.6212,
#  'lon': 37.7456,
#  'square': 25.0,
#  'metro_dist': 0.083,
#  'floor': 1,
#  'author_type': 'Агентство',
#  'object_type': 'Офисное помещение',
#  'metro_district': 'Шипиловская'}
