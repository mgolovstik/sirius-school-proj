# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv("../data/data_part2_transform.csv")
# data = data[data["Источник"] != "cian.ru"].copy()
data.head()
# Out:
#    Unnamed: 0          ID на сайте          Источник      Цена  \
# 0           4            317806989           cian.ru  170660.0
# 1          11            321218531           cian.ru  210000.0
# 2          13  3086827887246928315  realty.yandex.ru  400000.0
# 3          14            322749249           cian.ru   75000.0
# 4          17            321293952           cian.ru   63000.0
#
#                   Дата Тип автора                   Город      Метро/Район  \
# 0  2025-09-03 22:24:00  Агентство  Мытищи городской округ       Медведково
# 1  2025-08-29 14:21:56  Агентство                 Королев       Медведково
# 2  2025-09-12 15:59:21  Агентство              Котельники       Котельники
# 3  2025-10-10 10:21:45  Агентство                  Реутов  Северный Реутов
# 4  2025-09-21 08:23:54  Агентство   Химки городской округ  Пятницкое шоссе
#
#                   Адрес                                           Описание  \
# ...

# %%
data["Тип автора"] = data["Тип автора"].replace({"Частное лицо (фильтр)" : "Частное лицо"})

# %%
data["Тип автора"].unique()
# Out:
# array(['Агентство', 'Частное лицо'], dtype=object)

# %%
data["Moсква?"] = (data["Город"] == "Москва")

# %%
data["Moсква?"].sum()
# Out:
# np.int64(110)

# %%
data.to_csv("../data/data_part2_t.csv")
