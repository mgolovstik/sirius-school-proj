# %%
# !pip install pandas
# !pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../data/data_part2.csv")

# %% [markdown]
# # Обработка

# %%
data.head()
# Out:
#                                             Название     Цена  \
# 0  Торговая площадь в Московская область, Ленинск...   600000
# 1  Производственное помещение в Московская област...  2349809
# 2  Помещение свободного назначения в Московская о...   200000
# 3  Коммерческая земля в Московская область, Дмитр...    51000
# 4  Коммерческая земля в Московская область, Дмитр...    46750
#
#                   Дата      Телефон               Оператор  \
# 0  2025-10-19 22:29:04  89166030204  Мобильные ТелеСистемы
# 1  2025-10-19 22:29:03  89862742715           не определен
# 2  2025-10-19 22:28:45  89153024839  Мобильные ТелеСистемы
# 3  2025-10-19 22:28:42  89101553467  Мобильные ТелеСистемы
# 4  2025-10-19 22:28:42  89101553467  Мобильные ТелеСистемы
#
#        Контактное лицо (автор объявления) Тип автора              Регион  \
# 0                         Малина Проперти  Агентство  Московская область
# 1  Андрей Хмелевский (Апекс-Недвижимость)  Агентство  Московская область
# ...

# %%
data.isna().sum()
# Out:
# Название                                  0
# Цена                                      0
# Дата                                      0
# Телефон                                   0
# Оператор                                  0
# Контактное лицо (автор объявления)      102
# Тип автора                                0
# Регион                                    0
# Город                                     0
# Метро/Район                            7186
# Адрес                                  3529
# Описание                                328
# Тип объявления                            0
# Категория1                                0
# Категория2                                0
# ID на сайте                               0
# Источник                                  0
# lat                                       0
# lng                                       0
# Персона для контактов                 20000
# Доп.параметры                             0
# ...

# %%
data.columns
# Out:
# Index(['Название', 'Цена', 'Дата', 'Телефон', 'Оператор',
#        'Контактное лицо (автор объявления)', 'Тип автора', 'Регион', 'Город',
#        'Метро/Район', 'Адрес', 'Описание', 'Тип объявления', 'Категория1',
#        'Категория2', 'ID на сайте', 'Источник', 'lat', 'lng',
#        'Персона для контактов', 'Доп.параметры', 'URL', 'Ссылки на картинки',
#        'Регион мобильного телефона', 'Номер подменён',
#        'Расстояние до метро, км'],
#       dtype='object')

# %%
data = data.drop(['Телефон', 'Оператор', 'Контактное лицо (автор объявления)',
           'Номер подменён', 'Персона для контактов', 'Регион мобильного телефона',
           'Тип объявления', 'Категория1', 'Категория2'
], axis=1)

# %%
data.head()
# Out:
#                                             Название     Цена  \
# 0  Торговая площадь в Московская область, Ленинск...   600000
# 1  Производственное помещение в Московская област...  2349809
# 2  Помещение свободного назначения в Московская о...   200000
# 3  Коммерческая земля в Московская область, Дмитр...    51000
# 4  Коммерческая земля в Московская область, Дмитр...    46750
#
#                   Дата Тип автора              Регион  \
# 0  2025-10-19 22:29:04  Агентство  Московская область
# 1  2025-10-19 22:29:03  Агентство  Московская область
# 2  2025-10-19 22:28:45  Агентство  Московская область
# 3  2025-10-19 22:28:42  Агентство  Московская область
# 4  2025-10-19 22:28:42  Агентство  Московская область
#
#                              Город    Метро/Район  \
# 0        Ленинский городской округ  Домодедовская
# 1                          Пушкино     Мамонтовка
# 2                         Подольск       Подольск
# 3  Дмитровский муниципальный округ            NaN
# ...

# %%
data = data.set_index(['ID на сайте', 'Источник'])

# %%
data.loc[(320933693, "cian.ru")]
# Out:
# Название                   Торговая площадь в Московская область, Ленинск...
# Цена                                                                  600000
# Дата                                                     2025-10-19 22:29:04
# Тип автора                                                         Агентство
# Регион                                                    Московская область
# Город                                              Ленинский городской округ
# Метро/Район                                                    Домодедовская
# Адрес                                                     ш. Пригородное, 24
# Описание                   Аренда торгового помещения 229,7 м2 в пгт.Миса...
# lat                                                                 55.55552
# lng                                                                37.811267
# Доп.параметры              Этаж=1|Этажность здания=17|Тип объявления=Сдам...
# ...

# %%
data['Описание'] = 'НАЗВАНИЕ: ' + data['Название'] + '\n\n' + 'ОПИСАНИЕ: ' + data['Описание']

# %%
print(data.loc[(320933693, "cian.ru"), "Описание"])
# Out:
# НАЗВАНИЕ: Торговая площадь в Московская область, Ленинский городской округ, Мисайлово пгт ш. Пригородное, 24 (231 м²)
#
# ОПИСАНИЕ: Аренда торгового помещения 229,7 м2 в пгт.Мисайлово, Пригородное шоссе, д. 24 (15 минут транспортом от метро Зябликово). 1-я линия домов. Помещение 229,7 м2 располагается на 1 этаже, открытая планировка, отдельный вход с фасада на Литературный бульвар и один со двора, высота потолка 4 м, витринные окна по фасаду. Электрическая мощность 45 кВт. Помещение в бетоне. Парковка перед фасадом. Место для размещения рекламы на фасаде. Две мокрые точки. Помещение расположено в жилом комплексе  Пригород лесное . Напротив помещения расположена государственная поликлиника. Поликлиника во всем микрорайоне (в том числе существующая часть микрорайона) будет одна. Уже построена. Больше 100 метров от входа до входа. Прямая аренда от собственника, долгосрочный договор. Арендная плата 600 000 рублей в месяц. УС налогообложения. Без комиссии.

# %%
data.drop('Название', axis=1)
# Out:
#                                           Цена                 Дата  \
# ID на сайте         Источник
# 320933693           cian.ru             600000  2025-10-19 22:29:04
# 318910625           cian.ru            2349809  2025-10-19 22:29:03
# 320821721           cian.ru             200000  2025-10-19 22:28:45
# 322939017           cian.ru              51000  2025-10-19 22:28:42
# 322939018           cian.ru              46750  2025-10-19 22:28:42
# ...                                        ...                  ...
# 2361989403646345039 realty.yandex.ru    950000  2025-07-30 16:06:35
# 3051474340154638117 realty.yandex.ru     64800  2025-07-30 16:06:34
# 2361989405333673454 realty.yandex.ru  14634000  2025-07-30 16:06:34
# 3051474285929205993 realty.yandex.ru    389994  2025-07-30 16:06:33
# 2361989400807465320 realty.yandex.ru    205500  2025-07-30 16:06:33
#
#                                      Тип автора              Регион  \
# ID на сайте         Источник
# ...

# %%
data["Доп.параметры"].iloc[0]
# Out:
# 'Этаж=1|Этажность здания=17|Тип объявления=Сдам|Вид объекта=Торговое помещение|Общая площадь=231'

# %%
def parse_par(v):
    return dict(pair.split("=") for pair in v.split("|"))
parse_par(data["Доп.параметры"].iloc[0])
# Out:
# {'Этаж': '1',
#  'Этажность здания': '17',
#  'Тип объявления': 'Сдам',
#  'Вид объекта': 'Торговое помещение',
#  'Общая площадь': '231'}

# %%
_ = data["Доп.параметры"].apply(parse_par)
params_pars = pd.json_normalize(_)
params_pars.index = data.index

# %%
data.isna().sum() / params_pars.shape[0] * 100
# Out:
# Название                    0.000
# Цена                        0.000
# Дата                        0.000
# Тип автора                  0.000
# Регион                      0.000
# Город                       0.000
# Метро/Район                35.930
# Адрес                      17.645
# Описание                    1.640
# lat                         0.000
# lng                         0.000
# Доп.параметры               0.000
# URL                         0.000
# Ссылки на картинки          2.415
# Расстояние до метро, км     0.000
# dtype: float64

# %%
params_pars.nunique()
# Out:
# Этаж                       29
# Этажность здания           41
# Тип объявления              1
# Вид объекта                 8
# Общая площадь            3748
# Ед. измерения площади       2
# Категория                   3
# Класс здания                4
# dtype: int64

# %%
params_pars['Ед. измерения площади'].unique()
# Out:
# array([nan, 'сот.', 'га.'], dtype=object)

# %%
params_pars = params_pars.drop(['Тип объявления', 'Класс здания'], axis=1)

# %%
data = pd.concat([data.drop("Доп.параметры", axis=1), params_pars], axis=1)

# %%
data.dtypes
# Out:
# Название                    object
# Цена                         int64
# Дата                        object
# Тип автора                  object
# Регион                      object
# Город                       object
# Метро/Район                 object
# Адрес                       object
# Описание                    object
# lat                        float64
# lng                        float64
# URL                         object
# Ссылки на картинки          object
# Расстояние до метро, км     object
# Этаж                        object
# Этажность здания            object
# Вид объекта                 object
# Общая площадь               object
# Ед. измерения площади       object
# Категория                   object
# dtype: object

# %%
data["Дата"] = pd.to_datetime(data["Дата"])

# %%
data[["Расстояние до метро, км", "Этаж",
      "Этажность здания", "Общая площадь"
     ]]
# Out:
#                                      Расстояние до метро, км Этаж  \
# ID на сайте         Источник
# 320933693           cian.ru                           12.833    1
# 318910625           cian.ru                       неизвестно    1
# 320821721           cian.ru                              1.5    1
# 322939017           cian.ru                       неизвестно  NaN
# 322939018           cian.ru                       неизвестно  NaN
# ...                                                      ...  ...
# 2361989403646345039 realty.yandex.ru                       1    3
# 3051474340154638117 realty.yandex.ru                   13.75    3
# 2361989405333673454 realty.yandex.ru                  18.333    2
# 3051474285929205993 realty.yandex.ru                   0.667    1
# 2361989400807465320 realty.yandex.ru                   35.75    1
#
#                                      Этажность здания Общая площадь
# ID на сайте         Источник
# ...

# %%
data["Расстояние до метро, км"] = data["Расстояние до метро, км"].replace({"неизвестно" : np.nan})

# %%
data[["Расстояние до метро, км", "Этаж",
      "Этажность здания", "Общая площадь"
     ]] = data[["Расстояние до метро, км", "Этаж",
      "Этажность здания", "Общая площадь"
     ]].astype(float)

# %%
data[["Расстояние до метро, км", "Этаж",
      "Этажность здания", "Общая площадь"
     ]].dtypes
# Out:
# Расстояние до метро, км    float64
# Этаж                       float64
# Этажность здания           float64
# Общая площадь              float64
# dtype: object

# %%
data[["Общая площадь", "Ед. измерения площади"]]
# Out:
#                                       Общая площадь Ед. измерения площади
# ID на сайте         Источник
# 320933693           cian.ru                  231.00                   NaN
# 318910625           cian.ru                 3700.00                   NaN
# 320821721           cian.ru                  151.00                   NaN
# 322939017           cian.ru                    8.87                  сот.
# 322939018           cian.ru                    8.04                  сот.
# ...                                             ...                   ...
# 2361989403646345039 realty.yandex.ru         950.00                   NaN
# 3051474340154638117 realty.yandex.ru          54.00                   NaN
# 2361989405333673454 realty.yandex.ru        2439.00                   NaN
# 3051474285929205993 realty.yandex.ru         228.00                   NaN
# 2361989400807465320 realty.yandex.ru         137.00                   NaN
#
# [20000 rows x 2 columns]

# %%
data.loc[
    data["Ед. измерения площади"] == "сот.",
    "Общая площадь"] *= 100
data.loc[
    data["Ед. измерения площади"] == "га.",
    "Общая площадь"] *= 10000

# %%
data = data.drop("Ед. измерения площади", axis=1)

# %%
data.head()
# Out:
#                                                                Название  \
# ID на сайте Источник
# 320933693   cian.ru   Торговая площадь в Московская область, Ленинск...
# 318910625   cian.ru   Производственное помещение в Московская област...
# 320821721   cian.ru   Помещение свободного назначения в Московская о...
# 322939017   cian.ru   Коммерческая земля в Московская область, Дмитр...
# 322939018   cian.ru   Коммерческая земля в Московская область, Дмитр...
#
#                          Цена                Дата Тип автора  \
# ID на сайте Источник
# 320933693   cian.ru    600000 2025-10-19 22:29:04  Агентство
# 318910625   cian.ru   2349809 2025-10-19 22:29:03  Агентство
# 320821721   cian.ru    200000 2025-10-19 22:28:45  Агентство
# 322939017   cian.ru     51000 2025-10-19 22:28:42  Агентство
# 322939018   cian.ru     46750 2025-10-19 22:28:42  Агентство
#
#                                   Регион                            Город  \
# ID на сайте Источник
# ...

# %%
# !pip install -q matplotlib
# !pip install -q seaborn
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Не обработка

# %%
data.head()
# Out:
#                                                                Название  \
# ID на сайте Источник
# 320933693   cian.ru   Торговая площадь в Московская область, Ленинск...
# 318910625   cian.ru   Производственное помещение в Московская област...
# 320821721   cian.ru   Помещение свободного назначения в Московская о...
# 322939017   cian.ru   Коммерческая земля в Московская область, Дмитр...
# 322939018   cian.ru   Коммерческая земля в Московская область, Дмитр...
#
#                          Цена                Дата Тип автора  \
# ID на сайте Источник
# 320933693   cian.ru    600000 2025-10-19 22:29:04  Агентство
# 318910625   cian.ru   2349809 2025-10-19 22:29:03  Агентство
# 320821721   cian.ru    200000 2025-10-19 22:28:45  Агентство
# 322939017   cian.ru     51000 2025-10-19 22:28:42  Агентство
# 322939018   cian.ru     46750 2025-10-19 22:28:42  Агентство
#
#                                   Регион                            Город  \
# ID на сайте Источник
# ...

# %%
data["Цена м2"] = data["Цена"] / data["Общая площадь"]

# %%
mask1 = data["Цена"] > 1e8
mask2 = data["Цена м2"] > 40000
data[mask1 & mask2]
# Out:
#                                                                                Название  \
# ID на сайте         Источник
# 322881779           cian.ru           Здание в Московская область, Дмитровский муниц...
# 322324050           cian.ru           Склад в Московская область, Подольск городской...
# 322329506           cian.ru           Здание в Московская область, Рузский муниципал...
# 6251703067816753784 realty.yandex.ru                                     Склад (590 м²)
# 7567174384157601069 realty.yandex.ru               Производственное помещение (7000 м²)
# 321896881           cian.ru           Помещение свободного назначения в Московская о...
# 321897282           cian.ru           Помещение свободного назначения в Московская о...
# 321869367           cian.ru           Торговая площадь в Московская область, Чехов В...
# 320819279           cian.ru           Склад в Московская область, Балашиха городской...
# ...

# %% [markdown]
# # Graf

# %%
plt.hist(np.log1p(data["Цена"]), bins=30)
plt.show()

# %%
mask1 = (np.log1p(data["Цена"]) <= 20)
mask2 = (np.log1p(data["Цена"]) >= 4.5)
plt.hist(data["Цена"][mask1 & mask2], bins=30)
plt.show()

# %%
data = data[mask1 & mask2].copy()

# %%
data["Log(Цена)"] = np.log1p(data["Цена"])

# %%
sns.histplot(data, x="Log(Цена)", hue="Вид объекта", bins=50)
plt.show()

# %%
data["Log(Цена)"] = np.log1p(data["Цена"])

# %%
mask1 = (np.log1p(data["Цена"]) <= 17)
mask2 = (np.log1p(data["Цена"]) >= 10)
dfg = data[mask1 & mask2].groupby(by="Вид объекта")["Цена"].mean()
dfg.astype(int)
# Out:
# Вид объекта
# Гостиница                          1498400
# Здание                             1127769
# Коммерческая земля                  558172
# Офисное помещение                  1009746
# Помещение свободного назначения     455242
# Производственное помещение         2543126
# Складское помещение                3324114
# Торговое помещение                  425449
# Name: Цена, dtype: int64

# %%
mask1 = (np.log1p(data["Цена"]) <= 17)
mask2 = (np.log1p(data["Цена"]) >= 10)
sns.histplot(data[mask1 & mask2], x="Log(Цена)", hue="Вид объекта", bins=50)
plt.show()

# %%
sns.barplot(dfg)
plt.xticks(rotation=90)
plt.show()

# %%
types = ["Здание", "Производственное помещение", "Складское помещение"]

# %%
data.head()
# Out:
#                                                                Название  \
# ID на сайте Источник
# 320933693   cian.ru   Торговая площадь в Московская область, Ленинск...
# 318910625   cian.ru   Производственное помещение в Московская област...
# 320821721   cian.ru   Помещение свободного назначения в Московская о...
# 322939017   cian.ru   Коммерческая земля в Московская область, Дмитр...
# 322939018   cian.ru   Коммерческая земля в Московская область, Дмитр...
#
#                          Цена                Дата Тип автора  \
# ID на сайте Источник
# 320933693   cian.ru    600000 2025-10-19 22:29:04  Агентство
# 318910625   cian.ru   2349809 2025-10-19 22:29:03  Агентство
# 320821721   cian.ru    200000 2025-10-19 22:28:45  Агентство
# 322939017   cian.ru     51000 2025-10-19 22:28:42  Агентство
# 322939018   cian.ru     46750 2025-10-19 22:28:42  Агентство
#
#                                   Регион                            Город  \
# ID на сайте Источник
# ...

# %%
data[data["Общая площадь"] > 0.5e6]
# Out:
#                                                                Название  \
# ID на сайте Источник
# 321758249   cian.ru   Коммерческая земля в Московская область, Лотош...
# 321417535   cian.ru   Коммерческая земля в Московская область, Химки...
# 321232566   cian.ru   Коммерческая земля в Московская область, Пущин...
# 320088275   cian.ru   Коммерческая земля в Московская область, Наро-...
# 320881118   cian.ru   Коммерческая земля в Московская область, Ленин...
# 319434549   cian.ru   Коммерческая земля в Московская область, Клин ...
# 321089873   cian.ru   Коммерческая земля в Московская область, Пущин...
# 321564560   cian.ru   Коммерческая земля в Московская область, Одинц...
# 321151955   cian.ru   Коммерческая земля в Московская область, Егорь...
# 320747364   cian.ru   Коммерческая земля в Московская область, Пушки...
# 320565199   cian.ru   Коммерческая земля в Московская область, Пущин...
# 320037624   cian.ru   Коммерческая земля в Московская область, Пущин...
# ...

# %% [markdown]
# # Stop graf

# %%
data[data["Общая площадь"] > 4000]
# Out:
#                                                                Название  \
# ID на сайте Источник
# 321049362   cian.ru   Склад в Московская область, Жуковский 92к5 (21...
# 321947537   cian.ru   Производственное помещение в Московская област...
# 321947533   cian.ru   Производственное помещение в Московская област...
# 321947532   cian.ru   Склад в Московская область, Ступино городской ...
# 321947534   cian.ru   Склад в Московская область, Ступино городской ...
# ...                                                                 ...
# 319562636   cian.ru   Коммерческая земля в Московская область, Можай...
# 319562650   cian.ru   Коммерческая земля в Московская область, Колом...
# 319562651   cian.ru   Коммерческая земля в Московская область, Колом...
# 7553345025  avito.ru                        Склад класса А в Домодедово
# 320291118   cian.ru   Коммерческая земля в Московская область, Ленин...
#
#                           Цена                Дата Тип автора  \
# ...

# %%
data = data[data["Вид объекта"] != "Складское помещение"].copy()
data = data[data["Вид объекта"] != "Производственное помещение"].copy()
data = data[data["Вид объекта"] != "Офисное помещение"].copy()
data = data[data["Вид объекта"] != "Коммерческая земля"].copy()
data = data[data["Вид объекта"] != "Гостиница"].copy()
#data = data[data["Вид объекта"] != "Здание"].copy()
data = data[data["Общая площадь"] <= 2000].copy()
data = data[data["Общая площадь"] >= 20].copy()

# %%
data[data["Цена"] > 2e8]
# Out:
#                                                                Название  \
# ID на сайте Источник
# 322881779   cian.ru   Здание в Московская область, Дмитровский муниц...
# 322329506   cian.ru   Здание в Московская область, Рузский муниципал...
# 318072559   cian.ru   Торговая площадь в Московская область, Красног...
# 320327012   cian.ru   Здание в Московская область, Кашира Стрелецкая...
#
#                            Цена                Дата             Тип автора  \
# ID на сайте Источник
# 322881779   cian.ru   360000000 2025-10-14 16:27:52  Частное лицо (фильтр)
# 322329506   cian.ru   445500000 2025-09-29 12:21:47  Частное лицо (фильтр)
# 318072559   cian.ru   250000000 2025-08-09 12:23:38              Агентство
# 320327012   cian.ru   397100000 2025-07-31 14:25:22              Агентство
#
#                                   Регион                            Город  \
# ID на сайте Источник
# 322881779   cian.ru   Московская область  Дмитровский муниципальный округ
# ...

# %%
plt.hist(data["Цена"], bins=30)
plt.show()

# %%
data = data[data["Цена"] < 2e6].copy()
data = data[data["Цена"] > 20000].copy()

# %%
data
# Out:
#                                                                Название  \
# ID на сайте Источник
# 320933693   cian.ru   Торговая площадь в Московская область, Ленинск...
# 320821721   cian.ru   Помещение свободного назначения в Московская о...
# 319368554   cian.ru   Помещение свободного назначения в Московская о...
# 323058065   cian.ru   Помещение свободного назначения в Московская о...
# 321288658   cian.ru   Торговая площадь в Московская область, Люберцы...
# ...                                                                 ...
# 320292043   cian.ru   Помещение свободного назначения в Московская о...
# 320174530   cian.ru   Помещение свободного назначения в Московская о...
# 320292087   cian.ru   Помещение свободного назначения в Московская о...
# 320292071   cian.ru   Помещение свободного назначения в Московская о...
# 7629806448  avito.ru                              Свободного назначения
#
#                         Цена                Дата             Тип автора  \
# ...

# %%
data.drop("Категория", axis=1)
# Out:
#                                                                Название  \
# ID на сайте Источник
# 320933693   cian.ru   Торговая площадь в Московская область, Ленинск...
# 320821721   cian.ru   Помещение свободного назначения в Московская о...
# 319368554   cian.ru   Помещение свободного назначения в Московская о...
# 323058065   cian.ru   Помещение свободного назначения в Московская о...
# 321288658   cian.ru   Торговая площадь в Московская область, Люберцы...
# ...                                                                 ...
# 320292043   cian.ru   Помещение свободного назначения в Московская о...
# 320174530   cian.ru   Помещение свободного назначения в Московская о...
# 320292087   cian.ru   Помещение свободного назначения в Московская о...
# 320292071   cian.ru   Помещение свободного назначения в Московская о...
# 7629806448  avito.ru                              Свободного назначения
#
#                         Цена                Дата             Тип автора  \
# ...

# %%
data["Вид объекта"] = data["Вид объекта"].fillna("Неизвестно")

# %%
dfg = data.groupby(by="Вид объекта")["Цена"].mean()
dfg
# Out:
# Вид объекта
# Здание                             484127.764103
# Неизвестно                         418952.380952
# Помещение свободного назначения    291611.227286
# Торговое помещение                 306569.159682
# Name: Цена, dtype: float64

# %%
data[[data["Тип автора"]].unique()
# Out:
# array(['Агентство', 'Частное лицо (фильтр)', 'Частное лицо'], dtype=object)

# %%
dfg = data["Цена"] / data["Расстояние до метро, км"]
dfg.dropna()
plt.hist(dfg, bins=30)
plt.show()

# %%
data.reanme
