# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv("../data/data_part2_transform.csv")
# data = data[data["Источник"] != "cian.ru"].copy()
data.head()
# Out:
#            ID на сайте          Источник    Цена                 Дата  \
# 0            318908834           cian.ru  850000  2025-08-04 22:28:32
# 1  2361989377879266127  realty.yandex.ru  150000  2025-08-04 14:21:59
# 2            321724768           cian.ru  400000  2025-10-07 20:27:35
# 3            318320605           cian.ru  602000  2025-09-07 10:23:42
# 4            317806989           cian.ru  170660  2025-09-03 22:24:00
#
#   Тип автора                          Город    Метро/Район  \
# 0  Агентство                     Домодедово       Подольск
# 1  Агентство                        Еганово          Отдых
# 2  Агентство  Раменский муниципальный округ  Домодедовская
# 3  Агентство                          Лобня          Лобня
# 4  Агентство         Мытищи городской округ     Медведково
#
#                                      Адрес  \
# 0  Центральный мкр, ул. Промышленная, 11/5
# 1                       Автодорожная улица
# 2                                       4Б
# 3                        ул. Горького, 104
# 4                        ул. Ильинского, 8
#
#                                             Описание        lat        lng  \
# 0  НАЗВАНИЕ: Производственное помещение в Московс...  55.450241  37.769756
# 1  НАЗВАНИЕ: Склад (150 м²)\n\nОПИСАНИЕ: Лот №890...  55.537754  38.025900
# 2  НАЗВАНИЕ: Склад в Московская область, Раменски...  55.372488  38.145845
# 3  НАЗВАНИЕ: Склад в Московская область, Лобня ул...  56.013462  37.503522
# 4  НАЗВАНИЕ: Помещение свободного назначения в Мо...  55.984149  37.723394
#
#                                                URL  \
# 0    https://www.cian.ru/rent/commercial/318908834
# 1  https://realty.ya.ru/offer/2361989377879266127/
# 2    https://www.cian.ru/rent/commercial/321724768
# 3    https://www.cian.ru/rent/commercial/318320605
# 4    https://www.cian.ru/rent/commercial/317806989
#
#                                   Ссылки на картинки  Расстояние до метро, км  \
# 0  https://images.cdn-cian.ru/images/2530918512-1...                   22.917
# 1  https://avatars.mds.yandex.net/get-realty-offe...                   26.583
# 2  https://images.cdn-cian.ru/images/2625991318-1...                      NaN
# 3  https://images.cdn-cian.ru/images/sklad-lobnya...                    1.500
# 4  https://images.cdn-cian.ru/images/2496958701-1...                   19.250
#
#    Этаж  Этажность здания                      Вид объекта  Общая площадь  \
# 0   1.0               1.0       Производственное помещение          850.0
# 1   1.0               1.0              Складское помещение          150.0
# 2   1.0               1.0              Складское помещение         1000.0
# 3   1.0               2.0              Складское помещение          860.0
# 4   1.0               8.0  Помещение свободного назначения           64.0
#
#   Категория
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %% [markdown]
# # -----------------------------------------------------------------------

# %%
data["Цена"] = data["Цена"].astype(float)
data["Цена / м2"] = data["Цена"] / data["Общая площадь"]
data["Log(Цена)"] = np.log1p(data["Цена"])

sns.histplot(data["Цена"], bins=30)
plt.show()

# %%
def get_quantplot(series):
    quantiles = np.arange(0, 1.00, 0.01)
    q_values = series.quantile(quantiles)
    
    plt.figure(figsize=(10, 6))
    q_values.plot(kind='line', linewidth=2, marker='o', markersize=3)
    plt.title('График возрастания квантилей цены')
    plt.xlabel('Квантиль (0-1)')
    plt.ylabel('Значение')
    plt.grid(True, alpha=0.3)
    plt.show()

get_quantplot(data["Цена"])

# %%
sns.histplot(data["Цена"], bins=30)
plt.show()

# %%
data2 = data.copy()
mask = (data2["Цена"] >= data2["Цена"].quantile(0.97))
data2.loc[mask, "Цена"] /= 12.0
# data2.loc[mask, "Цена"] /= data2.loc[mask, "Общая площадь"]

sns.histplot(data2["Цена"], bins=30)
plt.show()

# %%
get_quantplot(data2["Цена"])

# %%
data2 = data2[data2["Цена"] <= 8e6].copy()
sns.histplot(data2["Цена"], bins=30)
plt.show()

# %%
get_quantplot(data2["Цена / м2"])

# %%
data2 = data2[(np.log1p(data2["Цена / м2"]) <= 10) & (np.log1p(data2["Цена / м2"]) >= 5)].copy()
sns.histplot(np.log1p(data2["Цена / м2"]), bins=30)
plt.show()

# %%
get_quantplot(data2["Цена / м2"])

# %%
sns.histplot(data2["Цена / м2"], bins=30)
plt.show()

# %%
data["Источник"].value_counts()
# Out:
# Источник
# cian.ru             16111
# realty.yandex.ru     3088
# avito.ru              801
# Name: count, dtype: int64

# %%
data = data2.copy()

data = data[data["Вид объекта"] != "Коммерческая земля"].copy()
data = data[data["Вид объекта"] != "Производственное помещение"].copy()
data = data[data["Вид объекта"] != "Складское помещение"].copy()
# data = data[data["Вид объекта"] != "Офисное помещение"].copy()
# data = data[data["Вид объекта"] != "Здание"].copy()
data = data[data["Вид объекта"] != "Гостиница"].copy()
data = data[data['Общая площадь'] <= 2000].copy()
data = data[data['Общая площадь'] >= 20].copy()

# %%
data["Вид объекта"].value_counts()
# Out:
# Вид объекта
# Помещение свободного назначения    3678
# Офисное помещение                  2567
# Торговое помещение                 1415
# Здание                              204
# Name: count, dtype: int64

# %%
sns.boxplot(data, y="Цена", hue="Вид объекта")
plt.show()

# %% [markdown]
# **TODO: объединить типы**

# %%
data["Общая площадь"].describe(percentiles=(0.1, 0.25, 0.5, 0.75, 0.9))
# Out:
# count    7888.000000
# mean      315.189579
# std       401.906378
# min        20.000000
# 10%        36.000000
# 25%        65.000000
# 50%       142.000000
# 75%       390.000000
# 90%       857.300000
# max      2000.000000
# Name: Общая площадь, dtype: float64

# %%
plt.hist(data['Общая площадь'], bins=30)
plt.show()

# %%
data = data[data["Цена"] <= 2000000].copy()
data = data[data["Цена"] >= 20000].copy()

n_bins = 10

data['Цена_bin'] = pd.cut(data['Цена'], bins=n_bins)
data['Цена_bin'].value_counts()
# Out:
# Цена_bin
# (18020.0, 218000.0]       3977
# (218000.0, 416000.0]      1526
# (416000.0, 614000.0]       646
# (614000.0, 812000.0]       444
# (812000.0, 1010000.0]      308
# (1010000.0, 1208000.0]     247
# (1208000.0, 1406000.0]     110
# (1406000.0, 1604000.0]      94
# (1604000.0, 1802000.0]      81
# (1802000.0, 2000000.0]      68
# Name: count, dtype: int64

# %%
plt.hist(data["Цена"], bins=30)
plt.show()

# %%
data["Цена"].describe(percentiles=(0.01, 0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 0.95)).astype(int)
# Out:
# count       7501
# mean      353141
# std       386173
# min        20000
# 1%         24000
# 5%         35100
# 10%        50000
# 25%       100000
# 50%       200000
# 75%       450000
# 90%       917273
# 95%      1200000
# max      2000000
# Name: Цена, dtype: int64

# %%
data.head()
# Out:
#             ID на сайте          Источник      Цена                 Дата  \
# 4             317806989           cian.ru  170660.0  2025-09-03 22:24:00
# 11            321218531           cian.ru  210000.0  2025-08-29 14:21:56
# 13  3086827887246928315  realty.yandex.ru  400000.0  2025-09-12 15:59:21
# 14            322749249           cian.ru   75000.0  2025-10-10 10:21:45
# 17            321293952           cian.ru   63000.0  2025-09-21 08:23:54
#
#    Тип автора                   Город      Метро/Район                 Адрес  \
# 4   Агентство  Мытищи городской округ       Медведково     ул. Ильинского, 8
# 11  Агентство                 Королев       Медведково   пл. Станционная, 21
# 13  Агентство              Котельники       Котельники  Дзержинское шоссе, 2
# 14  Агентство                  Реутов  Северный Реутов                   NaN
# 17  Агентство   Химки городской округ  Пятницкое шоссе                    83
#
#                                              Описание        lat  ...  \
# 4   НАЗВАНИЕ: Помещение свободного назначения в Мо...  55.984149  ...
# 11  НАЗВАНИЕ: Помещение свободного назначения в Мо...  55.927054  ...
# 13  НАЗВАНИЕ: Офис (200 м²)\n\nОПИСАНИЕ: Предлагае...  55.654476  ...
# 14  НАЗВАНИЕ: Помещение свободного назначения в Мо...  55.760565  ...
# 17  НАЗВАНИЕ: Помещение свободного назначения в Мо...  55.929041  ...
#
#                                    Ссылки на картинки Расстояние до метро, км  \
# 4   https://images.cdn-cian.ru/images/2496958701-1...                  19.250
# 11  https://images.cdn-cian.ru/images/nezhiloe-pom...                  23.833
# 13  https://avatars.mds.yandex.net/get-realty-offe...                  18.333
# 14  https://images.cdn-cian.ru/images/2661346770-1...                     NaN
# 17  https://images.cdn-cian.ru/images/nezhiloe-pom...                  15.583
#
#    Этаж  Этажность здания                      Вид объекта  Общая площадь  \
# 4   1.0               8.0  Помещение свободного назначения           64.0
# 11 -1.0               3.0  Помещение свободного назначения          300.0
# 13  4.0               5.0                Офисное помещение          200.0
# 14  1.0               1.0  Помещение свободного назначения           25.0
# 17 -1.0               3.0  Помещение свободного назначения           63.0
#
#    Категория  Цена / м2  Log(Цена)              Цена_bin
# 4        NaN  2666.5625  12.047434   (18020.0, 218000.0]
# 11       NaN   700.0000  12.254868   (18020.0, 218000.0]
# 13       NaN  2000.0000  12.899222  (218000.0, 416000.0]
# 14       NaN  3000.0000  11.225257   (18020.0, 218000.0]
# 17       NaN  1000.0000  11.050906   (18020.0, 218000.0]
#
# [5 rows x 22 columns]

# %%
data.isna().sum() / data.shape[0]
# Out:
# ID на сайте                0.000000
# Источник                   0.000000
# Цена                       0.000000
# Дата                       0.000000
# Тип автора                 0.000000
# Город                      0.000000
# Метро/Район                0.184242
# Адрес                      0.013065
# Описание                   0.000000
# lat                        0.000000
# lng                        0.000000
# URL                        0.000000
# Ссылки на картинки         0.017331
# Расстояние до метро, км    0.222770
# Этаж                       0.032662
# Этажность здания           0.057992
# Вид объекта                0.002800
# Общая площадь              0.000000
# Категория                  1.000000
# Цена / м2                  0.000000
# Log(Цена)                  0.000000
# Цена_bin                   0.000000
# dtype: float64

# %%
data = data.drop(["Категория", "Цена_bin"], axis=1)

# %%
data["Вид объекта"] = data["Вид объекта"].replace({"Помещение свободного назначения" : "Торговое / Свободного назначения", "Офисное помещение" : "Офис / Здание", "Здание" : "Офис / Здание", "Торговое помещение" : "Торговое / Свободного назначения"})

# %%
data = data.dropna(subset = ["Вид объекта"])

# %%
data[data["Город"] == "Москва"]
# Out:
#                ID на сайте          Источник       Цена                 Дата  \
# 180    6123951070909443577  realty.yandex.ru   897875.0  2025-08-08 08:02:40
# 210    3965285094498875461  realty.yandex.ru   175449.0  2025-10-17 14:59:28
# 231    6123813597476760358  realty.yandex.ru   927500.0  2025-09-11 08:04:30
# 1242   6858718382608590634  realty.yandex.ru  1615380.0  2025-08-05 04:05:21
# 1284   6123232169852737871  realty.yandex.ru  1037500.0  2025-09-19 15:03:03
# ...                    ...               ...        ...                  ...
# 18417  6123812992199249916  realty.yandex.ru  1132059.0  2025-09-11 08:04:40
# 19018  3090925258328637212  realty.yandex.ru   175450.0  2025-09-22 15:59:24
# 19491  3965285094500598566  realty.yandex.ru   312000.0  2025-09-25 08:59:06
# 19618  3086824645195981622  realty.yandex.ru   127233.0  2025-09-22 15:59:25
# 19898  6123232778680263037  realty.yandex.ru   929250.0  2025-09-19 15:02:53
#
#       Тип автора   Город Метро/Район                   Адрес  \
# 180    Агентство  Москва   Зябликово     Михневская улица, 8
# 210    Агентство  Москва   Зябликово     Михневская улица, 8
# 231    Агентство  Москва   Зябликово     Михневская улица, 8
# 1242   Агентство  Москва  Немчиновка  Можайское шоссе, 165с4
# 1284   Агентство  Москва   Зябликово     Михневская улица, 8
# ...          ...     ...         ...                     ...
# 18417  Агентство  Москва   Зябликово     Михневская улица, 8
# 19018  Агентство  Москва   Зябликово     Михневская улица, 8
# 19491  Агентство  Москва  Покровское      Ягодная улица, 8к3
# 19618  Агентство  Москва   Зябликово     Михневская улица, 8
# 19898  Агентство  Москва   Зябликово     Михневская улица, 8
#
#                                                 Описание        lat  \
# 180    НАЗВАНИЕ: Офис (718.3 м²)\n\nОПИСАНИЕ: Описани...  55.579380
# 210    НАЗВАНИЕ: Офис (95 м²)\n\nОПИСАНИЕ: АРЕНДА ОТ ...  55.579380
# 231    НАЗВАНИЕ: Офис (742 м²)\n\nОПИСАНИЕ: Описание ...  55.579380
# 1242   НАЗВАНИЕ: Офис (1140 м²)\n\nОПИСАНИЕ: Лот №796...  55.711530
# 1284   НАЗВАНИЕ: Офис (830 м²)\n\nОПИСАНИЕ: Описание ...  55.579380
# ...                                                  ...        ...
# 18417  НАЗВАНИЕ: Офис (799.1 м²)\n\nОПИСАНИЕ: Описани...  55.579380
# 19018  НАЗВАНИЕ: Офис (95.7 м²)\n\nОПИСАНИЕ: Сдается ...  55.579380
# 19491  НАЗВАНИЕ: Офис (208 м²)\n\nОПИСАНИЕ: АРЕНДА ОТ...  55.576637
# 19618  НАЗВАНИЕ: Офис (69.4 м²)\n\nОПИСАНИЕ: Аренда о...  55.579380
# 19898  НАЗВАНИЕ: Офис (743.4 м²)\n\nОПИСАНИЕ: Описани...  55.579380
#
#              lng                                              URL  \
# 180    37.671062  https://realty.ya.ru/offer/6123951070909443577/
# 210    37.671062  https://realty.ya.ru/offer/3965285094498875461/
# 231    37.671062  https://realty.ya.ru/offer/6123813597476760358/
# 1242   37.380634  https://realty.ya.ru/offer/6858718382608590634/
# 1284   37.671062  https://realty.ya.ru/offer/6123232169852737871/
# ...          ...                                              ...
# 18417  37.671062  https://realty.ya.ru/offer/6123812992199249916/
# 19018  37.671062  https://realty.ya.ru/offer/3090925258328637212/
# 19491  37.673016  https://realty.ya.ru/offer/3965285094500598566/
# 19618  37.671062  https://realty.ya.ru/offer/3086824645195981622/
# 19898  37.671062  https://realty.ya.ru/offer/6123232778680263037/
#
#                                       Ссылки на картинки  \
# 180    https://avatars.mds.yandex.net/get-realty-offe...
# 210    https://avatars.mds.yandex.net/get-realty-offe...
# 231    https://avatars.mds.yandex.net/get-realty-offe...
# 1242   https://avatars.mds.yandex.net/get-realty-offe...
# 1284   https://avatars.mds.yandex.net/get-realty-offe...
# ...                                                  ...
# 18417  https://avatars.mds.yandex.net/get-realty-offe...
# 19018  https://avatars.mds.yandex.net/get-realty-offe...
# 19491  https://avatars.mds.yandex.net/get-realty-offe...
# 19618  https://avatars.mds.yandex.net/get-realty-offe...
# 19898  https://avatars.mds.yandex.net/get-realty-offe...
#
#        Расстояние до метро, км  Этаж  Этажность здания    Вид объекта  \
# 180                     18.333  45.0              45.0  Офис / Здание
# 210                     18.333   1.0              25.0  Офис / Здание
# 231                     18.333  45.0              45.0  Офис / Здание
# 1242                     1.083   8.0               8.0  Офис / Здание
# 1284                    18.333   0.0              45.0  Офис / Здание
# ...                        ...   ...               ...            ...
# 18417                   18.333   1.0              45.0  Офис / Здание
# 19018                   18.333   1.0              45.0  Офис / Здание
# 19491                   22.000   1.0              25.0  Офис / Здание
# 19618                   18.333   1.0              45.0  Офис / Здание
# 19898                   18.333  45.0              45.0  Офис / Здание
#
#        Общая площадь    Цена / м2  Log(Цена)
# 180            718.3  1250.000000  13.707787
# 210             95.0  1846.831579  12.075109
# 231            742.0  1250.000000  13.740249
# 1242          1140.0  1417.000000  14.295081
# 1284           830.0  1250.000000  13.852325
# ...              ...          ...        ...
# 18417          799.1  1416.667501  13.939550
# 19018           95.7  1833.333333  12.075115
# 19491          208.0  1500.000000  12.650762
# 19618           69.4  1833.328530  11.753783
# 19898          743.4  1250.000000  13.742134
#
# [110 rows x 20 columns]
