# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_excel("../data_transformed.xlsx")
# data = data[data["Источник"] != "cian.ru"].copy()
data.head()
# Out:
#    ID на сайте  Источник    Цена                Дата             Тип автора  \
# 0    309857268   cian.ru   45603 2025-03-19 23:21:56              Агентство
# 1    319248874   cian.ru  200000 2025-06-30 12:21:44              Агентство
# 2    320077925   cian.ru  300000 2025-08-05 14:23:40              Агентство
# 3    318455773   cian.ru  375000 2025-06-06 10:29:07  Частное лицо (фильтр)
# 4   4719475341  avito.ru   80000 2025-02-11 12:22:13              Агентство
#
#                                Город Метро/Район  \
# 0  Волоколамский муниципальный округ         NaN
# 1                              Чехов         NaN
# 2                           Балашиха  Новокосино
# 3                            Королев  Медведково
# 4                         Котельники  Котельники
#
#                                                Адрес  \
# 0                                                NaN
# 1                                    ул. Чехова, 4с1
# 2                                         Заря мкр,
# 3                    Первомайский мкр, ул. Кирова, 2
# 4  Московская обл., Котельники, 1-й Покровский пр...
#
#                                             Описание        lat        lng  \
# 0  НАЗВАНИЕ: Коммерческая земля в Московская обла...  56.194373  36.260946
# 1  НАЗВАНИЕ: Помещение свободного назначения в Мо...  55.146630  37.482484
# 2  НАЗВАНИЕ: Склад в Московская область, Балашиха...  55.758802  38.079414
# 3  НАЗВАНИЕ: Помещение свободного назначения в Мо...  55.934618  37.873745
# 4  НАЗВАНИЕ: Мега Белая Дача, прикасса Ашана, тор...  55.653299  37.844217
#
#                                                  URL  \
# 0      https://www.cian.ru/rent/commercial/309857268
# 1      https://www.cian.ru/rent/commercial/319248874
# 2      https://www.cian.ru/rent/commercial/320077925
# 3      https://www.cian.ru/rent/commercial/318455773
# 4  https://www.avito.ru/kotelniki/kommercheskaya_...
#
#                                   Ссылки на картинки  Расстояние до метро, км  \
# 0  https://images.cdn-cian.ru/images/2322472437-1...                      NaN
# 1  https://images.cdn-cian.ru/images/nezhiloe-pom...                      NaN
# 2  https://images.cdn-cian.ru/images/sklad-zarya-...                   17.417
# 3  https://images.cdn-cian.ru/images/nezhiloe-pom...                   25.667
# 4  https://20.img.avito.st/image/1/1.JC7mtLa5iMfQ...                    2.500
#
#            Категория                      Вид объекта  Общая площадь  Этаж  \
# 0  Участок поселений               Коммерческая земля         2375.0   NaN
# 1                NaN  Помещение свободного назначения          313.0   1.0
# 2                NaN              Складское помещение          300.0   1.0
# 3                NaN  Помещение свободного назначения          250.0   2.0
# 4                NaN               Торговое помещение           14.0   1.0
#
#    Этажность здания
# 0               NaN
# 1               2.0
# 2               1.0
# 3               2.0
# 4               NaN

# %% [markdown]
# # -----------------------------------------------------------------------

# %%
data["Цена"] = data["Цена"].astype(float)
data["Цена / м2"] = data["Цена"] / data["Общая площадь"]
data["Log(Цена)"] = np.log1p(data["Цена"])

sns.histplot(data["Цена"], bins=30)
plt.show()

# %%
def get_quantplot(series):
    quantiles = np.arange(0, 1.00, 0.01)
    q_values = series.quantile(quantiles)
    
    plt.figure(figsize=(10, 6))
    q_values.plot(kind='line', linewidth=2, marker='o', markersize=3)
    plt.title('График возрастания квантилей цены')
    plt.xlabel('Квантиль (0-1)')
    plt.ylabel('Значение')
    plt.grid(True, alpha=0.3)
    plt.show()

get_quantplot(data["Цена"])

# %%
sns.histplot(data["Цена"], bins=30)
plt.show()

# %%
data2 = data.copy()
mask = (data2["Цена"] >= data2["Цена"].quantile(0.97))
data2.loc[mask, "Цена"] /= 12.0
# data2.loc[mask, "Цена"] /= data2.loc[mask, "Общая площадь"]

sns.histplot(data2["Цена"], bins=30)
plt.show()

# %%
get_quantplot(data2["Цена"])

# %%
data2 = data2[data2["Цена"] <= 8e6].copy()
sns.histplot(data2["Цена"], bins=30)
plt.show()

# %%
get_quantplot(data2["Цена / м2"])

# %%
data2 = data2[(np.log1p(data2["Цена / м2"]) <= 10) & (np.log1p(data2["Цена / м2"]) >= 5)].copy()
sns.histplot(np.log1p(data2["Цена / м2"]), bins=30)
plt.show()

# %%
get_quantplot(data2["Цена / м2"])

# %%
sns.histplot(data2["Цена / м2"], bins=30)
plt.show()

# %%
data["Источник"].value_counts()
# Out:
# Источник
# cian.ru             13687
# avito.ru             4206
# realty.yandex.ru     2063
# Name: count, dtype: int64

# %%
data = data2.copy()

data = data[data["Вид объекта"] != "Коммерческая земля"].copy()
data = data[data["Вид объекта"] != "Производственное помещение"].copy()
data = data[data["Вид объекта"] != "Складское помещение"].copy()
# data = data[data["Вид объекта"] != "Офисное помещение"].copy()
# data = data[data["Вид объекта"] != "Здание"].copy()
data = data[data["Вид объекта"] != "Гостиница"].copy()
data = data[data['Общая площадь'] <= 2000].copy()
data = data[data['Общая площадь'] >= 20].copy()

# %%
data["Вид объекта"].value_counts()
# Out:
# Вид объекта
# Помещение свободного назначения    3615
# Офисное помещение                  2085
# Торговое помещение                 1230
# Здание                              154
# Name: count, dtype: int64

# %%
sns.boxplot(data, y="Цена", hue="Вид объекта")
plt.show()

# %% [markdown]
# **TODO: объединить типы**

# %%
data["Общая площадь"].describe(percentiles=(0.1, 0.25, 0.5, 0.75, 0.9))
# Out:
# count    7162.000000
# mean      296.486208
# std       386.515830
# min        20.000000
# 10%        34.000000
# 25%        60.000000
# 50%       128.000000
# 75%       356.825000
# 90%       821.000000
# max      2000.000000
# Name: Общая площадь, dtype: float64

# %%
plt.hist(data['Общая площадь'], bins=30)
plt.show()

# %%
data = data[data["Цена"] <= 2000000].copy()
data = data[data["Цена"] >= 20000].copy()

n_bins = 10

data['Цена_bin'] = pd.cut(data['Цена'], bins=n_bins)
data['Цена_bin'].value_counts()
# Out:
# Цена_bin
# (18020.0, 218000.0]       3817
# (218000.0, 416000.0]      1346
# (416000.0, 614000.0]       575
# (614000.0, 812000.0]       336
# (812000.0, 1010000.0]      276
# (1010000.0, 1208000.0]     178
# (1208000.0, 1406000.0]     105
# (1604000.0, 1802000.0]      71
# (1406000.0, 1604000.0]      66
# (1802000.0, 2000000.0]      50
# Name: count, dtype: int64

# %%
plt.hist(data["Цена"], bins=30)
plt.show()

# %%
data["Цена"].describe(percentiles=(0.01, 0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 0.95)).astype(int)
# Out:
# count       6820
# mean      330134
# std       368576
# min        20000
# 1%         22849
# 5%         35000
# 10%        50000
# 25%        90256
# 50%       189588
# 75%       400000
# 90%       865200
# 95%      1150099
# max      2000000
# Name: Цена, dtype: int64

# %%
data.head()
# Out:
#     ID на сайте  Источник      Цена                Дата  \
# 1     319248874   cian.ru  200000.0 2025-06-30 12:21:44
# 3     318455773   cian.ru  375000.0 2025-06-06 10:29:07
# 5     322037659   cian.ru  120000.0 2025-10-30 14:25:45
# 11    314087104   cian.ru  206400.0 2025-02-24 12:23:57
# 17   7253895329  avito.ru  128200.0 2025-03-26 02:33:16
#
#                Тип автора                      Город    Метро/Район  \
# 1               Агентство                      Чехов            NaN
# 3   Частное лицо (фильтр)                    Королев     Медведково
# 5               Агентство  Ленинский городской округ  Домодедовская
# 11              Агентство                      Химки    Беломорская
# 17              Агентство                  Андреевка            NaN
#
#                                                 Адрес  \
# 1                                     ул. Чехова, 4с1
# 3                     Первомайский мкр, ул. Кирова, 2
# 5                                                  18
# 11                                   ул. Репина, 2/27
# 17  Московская обл., г.о. Солнечногорск, д. Голубо...
#
#                                              Описание        lat  ...  \
# 1   НАЗВАНИЕ: Помещение свободного назначения в Мо...  55.146630  ...
# 3   НАЗВАНИЕ: Помещение свободного назначения в Мо...  55.934618  ...
# 5   НАЗВАНИЕ: Помещение свободного назначения в Мо...  55.584436  ...
# 11  НАЗВАНИЕ: Помещение свободного назначения в Мо...  55.900925  ...
# 17  НАЗВАНИЕ: Свободного назначения, 128.2 м²\n\nО...  55.982870  ...
#
#                                    Ссылки на картинки Расстояние до метро, км  \
# 1   https://images.cdn-cian.ru/images/nezhiloe-pom...                     NaN
# 3   https://images.cdn-cian.ru/images/nezhiloe-pom...                  25.667
# 5   https://images.cdn-cian.ru/images/2635872693-1...                   5.500
# 11  https://images.cdn-cian.ru/images/nezhiloe-pom...                   7.333
# 17  https://80.img.avito.st/image/1/1.6eJQZra5RQtm...                     NaN
#
#    Категория                      Вид объекта Общая площадь Этаж  \
# 1        NaN  Помещение свободного назначения         313.0  1.0
# 3        NaN  Помещение свободного назначения         250.0  2.0
# 5        NaN  Помещение свободного назначения          74.0 -1.0
# 11       NaN  Помещение свободного назначения         138.0  7.0
# 17       NaN  Помещение свободного назначения         128.2  1.0
#
#     Этажность здания    Цена / м2  Log(Цена)              Цена_bin
# 1                2.0   638.977636  12.206078   (18020.0, 218000.0]
# 3                2.0  1500.000000  12.834684  (218000.0, 416000.0]
# 5               19.0  1621.621622  11.695255   (18020.0, 218000.0]
# 11               9.0  1495.652174  12.237576   (18020.0, 218000.0]
# 17               NaN  1000.000000  11.761355   (18020.0, 218000.0]
#
# [5 rows x 22 columns]

# %%
data.isna().sum() / data.shape[0]
# Out:
# ID на сайте                0.000000
# Источник                   0.000000
# Цена                       0.000000
# Дата                       0.000000
# Тип автора                 0.000000
# Город                      0.000000
# Метро/Район                0.296334
# Адрес                      0.011877
# Описание                   0.000000
# lat                        0.000000
# lng                        0.000000
# URL                        0.000000
# Ссылки на картинки         0.081232
# Расстояние до метро, км    0.355279
# Категория                  1.000000
# Вид объекта                0.010704
# Общая площадь              0.000000
# Этаж                       0.026833
# Этажность здания           0.321408
# Цена / м2                  0.000000
# Log(Цена)                  0.000000
# Цена_bin                   0.000000
# dtype: float64

# %%
data = data.drop(["Категория", "Цена_bin"], axis=1)
