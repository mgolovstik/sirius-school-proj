# %%
import pandas as pd
import numpy as np
import sklearn as sl

df = pd.read_csv("../../data/data_transformed_main.csv").set_index([p"ID на сайте", "Источник"])
df.head()
# Out:
#                            Цена                 Дата    Тип автора  \
# ID на сайте Источник
# 321970859   cian.ru     34500.0  2025-12-17 08:36:40     Агентство
# 323570959   cian.ru    160500.0  2025-12-17 08:36:40  Частное лицо
# 319937619   cian.ru   1226740.0  2025-12-17 08:36:40     Агентство
# 319936797   cian.ru    236480.0  2025-12-17 08:36:39     Агентство
# 319938233   cian.ru   1537120.0  2025-12-17 08:36:38     Агентство
#
#                                               Город           Метро/Район  \
# ID на сайте Источник
# 321970859   cian.ru                           Химки           Беломорская
# 323570959   cian.ru   Солнечногорск городской округ  Зеленоград — Крюково
# 319937619   cian.ru                          Мытищи            Медведково
# 319936797   cian.ru                          Мытищи            Медведково
# 319938233   cian.ru                          Мытищи            Медведково
#
#                                    Адрес  \
# ID на сайте Источник
# 321970859   cian.ru       Рабочая ул., 2
# 323570959   cian.ru                  21А
# 319937619   cian.ru   ул. Колпакова, 46А
# 319936797   cian.ru   ул. Колпакова, 46А
# 319938233   cian.ru   ул. Колпакова, 46А
#
#                                                                Описание  \
# ID на сайте Источник
# 321970859   cian.ru   НАЗВАНИЕ: Офис в Московская область, Химки Раб...
# 323570959   cian.ru   НАЗВАНИЕ: Торговая площадь в Московская област...
# 319937619   cian.ru   НАЗВАНИЕ: Офис в Московская область, Мытищи ул...
# 319936797   cian.ru   НАЗВАНИЕ: Офис в Московская область, Мытищи ул...
# 319938233   cian.ru   НАЗВАНИЕ: Офис в Московская область, Мытищи ул...
#
#                             lat        lng  \
# ID на сайте Источник
# 321970859   cian.ru   55.908036  37.432951
# 323570959   cian.ru   55.972650  37.099604
# 319937619   cian.ru   55.925178  37.718300
# 319936797   cian.ru   55.925178  37.718300
# 319938233   cian.ru   55.925178  37.718300
#
#                                                                 URL  \
# ID на сайте Источник
# 321970859   cian.ru   https://www.cian.ru/rent/commercial/321970859
# 323570959   cian.ru   https://www.cian.ru/rent/commercial/323570959
# 319937619   cian.ru   https://www.cian.ru/rent/commercial/319937619
# 319936797   cian.ru   https://www.cian.ru/rent/commercial/319936797
# 319938233   cian.ru   https://www.cian.ru/rent/commercial/319938233
#
#                                                      Ссылки на картинки  \
# ID на сайте Источник
# 321970859   cian.ru   https://images.cdn-cian.ru/images/2633983674-1...
# 323570959   cian.ru   https://images.cdn-cian.ru/images/torgovoe-pom...
# 319937619   cian.ru   https://images.cdn-cian.ru/images/2634163777-1...
# 319936797   cian.ru   https://images.cdn-cian.ru/images/2634163921-1...
# 319938233   cian.ru   https://images.cdn-cian.ru/images/2569099478-1...
#
#                       Расстояние до метро, км  Этаж  Этажность здания  \
# ID на сайте Источник
# 321970859   cian.ru                     9.167   4.0               4.0
# 323570959   cian.ru                     9.167   1.0               1.0
# 319937619   cian.ru                     9.167   2.0               6.0
# 319936797   cian.ru                     9.167   2.0               6.0
# 319938233   cian.ru                     9.167   2.0               6.0
#
#                                      Вид объекта  Общая площадь  Цена / м2  \
# ID на сайте Источник
# 321970859   cian.ru                Офис / Здание           23.0     1500.0
# 323570959   cian.ru   Торговое / свободного вида          107.0     1500.0
# 319937619   cian.ru                Офис / Здание          830.0     1478.0
# 319936797   cian.ru                Офис / Здание          160.0     1478.0
# 319938233   cian.ru                Офис / Здание         1040.0     1478.0
#
#                      Москва?
# ID на сайте Источник
# 321970859   cian.ru      0.0
# 323570959   cian.ru      0.0
# 319937619   cian.ru      0.0
# 319936797   cian.ru      0.0
# 319938233   cian.ru      0.0

# %%
from sklearn.preprocessing import (
    OneHotEncoder, OrdinalEncoder, TargetEncoder,
    StandardScaler, MinMaxScaler, RobustScaler,
)

from sklearn.linear_model import (
    LinearRegression, Ridge, Lasso, QuantileRegressor
)

from sklearn.metrics import (
    r2_score,
    root_mean_squared_error as rmse,
    mean_absolute_percentage_error as mape,
)
