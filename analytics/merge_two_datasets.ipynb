# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("../data/moscow_super_transformed.csv").set_index(['ID на сайте', 'Источник'])
df2 = pd.read_csv("../data/moscow_super_transformed_2.csv").set_index(['ID на сайте', 'Источник'])

# %%
df1
# Out:
#                                        district_name  n_buildings_300m  \
# ID на сайте         Источник
# 320731003           cian.ru                Зябликово              38.0
# 321876001           cian.ru              Хорошевский              54.0
# 322186790           cian.ru                Таганский              44.0
# 321392086           cian.ru             Бутово Южное              23.0
# 324943206           cian.ru             Останкинский              46.0
# ...                                              ...               ...
# 2361989407165763072 realty.yandex.ru         Донской              47.0
# 319013189           cian.ru             Марьина Роща              72.0
# 3966105355571245056 realty.yandex.ru     Обручевский              37.0
# 3986832478441152000 realty.yandex.ru  Филевский Парк              48.0
# 8660284132704650240 realty.yandex.ru     Даниловский              26.0
#
#                                       n_living_buildings_300m  n_flats_300m  \
# ...

# %%
df2
# Out:
#                                       district_name  n_buildings_300m  \
# ID на сайте         Источник
# 2361982363910666240 realty.yandex.ru  Ломоносовский              39.0
# 324514270           cian.ru           Ломоносовский              40.0
# 323292280           cian.ru           Ломоносовский              40.0
# 319684273           cian.ru                Бибирево              32.0
# 3051474308312615936 realty.yandex.ru  Ломоносовский              39.0
# ...                                             ...               ...
# 324829822           cian.ru             Пресненский              21.0
# 324883207           cian.ru             Пресненский              21.0
# 322901132           cian.ru                   Арбат             109.0
# 3966105355551019008 realty.yandex.ru          Арбат             109.0
# 323451346           cian.ru             Пресненский              12.0
#
#                                       n_living_buildings_300m  n_flats_300m  \
# ...

# %%
df = pd.concat([df1, df2], axis=0)
df
# Out:
#                                      district_name  n_buildings_300m  \
# ID на сайте         Источник
# 320731003           cian.ru              Зябликово              38.0
# 321876001           cian.ru            Хорошевский              54.0
# 322186790           cian.ru              Таганский              44.0
# 321392086           cian.ru           Бутово Южное              23.0
# 324943206           cian.ru           Останкинский              46.0
# ...                                            ...               ...
# 324829822           cian.ru            Пресненский              21.0
# 324883207           cian.ru            Пресненский              21.0
# 322901132           cian.ru                  Арбат             109.0
# 3966105355551019008 realty.yandex.ru         Арбат             109.0
# 323451346           cian.ru            Пресненский              12.0
#
#                                       n_living_buildings_300m  n_flats_300m  \
# ID на сайте         Источник
# ...

# %%
df_cleaned = df.drop_duplicates().copy()
df_cleaned
# Out:
#                                      district_name  n_buildings_300m  \
# ID на сайте         Источник
# 320731003           cian.ru              Зябликово              38.0
# 321876001           cian.ru            Хорошевский              54.0
# 322186790           cian.ru              Таганский              44.0
# 321392086           cian.ru           Бутово Южное              23.0
# 324943206           cian.ru           Останкинский              46.0
# ...                                            ...               ...
# 323352679           cian.ru              Таганский             133.0
# 3786967450365862912 realty.yandex.ru   Пресненский              19.0
# 8660284132701755392 realty.yandex.ru     Мещанский             119.0
# 3965285094530994176 realty.yandex.ru      Тверской             136.0
# 3966105355551019008 realty.yandex.ru         Арбат             109.0
#
#                                       n_living_buildings_300m  n_flats_300m  \
# ID на сайте         Источник
# ...

# %%
df_cleaned.to_csv("../data/moscow_super_transformed.csv")
