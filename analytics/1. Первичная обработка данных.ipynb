# %%
import pandas as pd
import numpy as np

data = pd.read_csv("../data/data_part3.csv")
data = data.sample(20000).copy()

# %%
data.head()
# Out:
#                                                 Название     Цена  \
# 19203  Склад в Московская область, Мытищи городской о...  1650000
# 201    Помещение свободного назначения в Московская о...    35000
# 9441   Коммерческая земля в Московская область, Чехов...    85493
# 13870                        Свободного назначения, 9 м²    20700
# 10305  Склад в Московская область, Раменский муниципа...  2333300
#
#                       Дата      Телефон               Оператор  \
# 19203  2025-06-11 12:46:18  89921281045           не определен
# 201    2025-07-30 08:23:45  89863238002           не определен
# 9441   2025-07-06 02:24:32  89153135209  Мобильные ТелеСистемы
# 13870  2025-06-25 14:34:03  89675540522                    МТТ
# 10305  2025-07-04 00:24:47  89169577006  Мобильные ТелеСистемы
#
#                       Контактное лицо (автор объявления) Тип автора  \
# 19203  CRE Department (HERZEN. Индустриальная Недвижи...  Агентство
# 201                                 Капитал Недвижимость  Агентство
# 9441   Министерство инвестиций, промышленности и наук...  Агентство
# 13870                                             Михаил  Агентство
# 10305                    Отдел продаж INVEST 7 (INVEST7)  Агентство
#
#                    Регион                          Город  Метро/Район  ...  \
# 19203  Московская область         Мытищи городской округ        Лобня  ...
# 201    Московская область                          Химки  Беломорская  ...
# 9441   Московская область      Чехов муниципальный округ          NaN  ...
# 13870  Московская область                        Люберцы   Котельники  ...
# 10305  Московская область  Раменский муниципальный округ    Раменское  ...
#
#        Источник        lat        lng Персона для контактов  \
# 19203   cian.ru  56.023751  37.502022                   NaN
# 201     cian.ru  55.908444  37.433409                   NaN
# 9441    cian.ru  55.146462  37.300215                   NaN
# 13870  avito.ru  55.678056  37.865076                   NaN
# 10305   cian.ru  55.600979  38.462743                   NaN
#
#                                            Доп.параметры  \
# 19203  Этаж=1|Этажность здания=1|Тип объявления=Сдам|...
# 201    Этаж=3|Этажность здания=7|Тип объявления=Сдам|...
# 9441   Ед. измерения площади=сот.|Категория=Сельхозна...
# 13870  Этаж=1|Тип объявления=Сдам|Вид объекта=Помещен...
# 10305  Этаж=1|Этажность здания=1|Тип объявления=Сдам|...
#
#                                                      URL  \
# 19203      https://www.cian.ru/rent/commercial/318640420
# 201        https://www.cian.ru/rent/commercial/320032234
# 9441       https://www.cian.ru/rent/commercial/319196407
# 13870  https://www.avito.ru/lyubertsy/kommercheskaya_...
# 10305      https://www.cian.ru/rent/commercial/317908616
#
#                                       Ссылки на картинки  \
# 19203  https://images.cdn-cian.ru/images/2520883320-1...
# 201    https://images.cdn-cian.ru/images/nezhiloe-pom...
# 9441   https://images.cdn-cian.ru/images/2543367737-1...
# 13870  https://80.img.avito.st/image/1/1._E03Ira5UKQB...
# 10305  https://images.cdn-cian.ru/images/2499464006-1...
#
#            Регион мобильного телефона  Номер подменён  Расстояние до метро, км
# 19203                    не определен              да                      5.5
# 201                      не определен              да                    9.167
# 9441   г. Москва и Московская область              да               неизвестно
# 13870            Свердловская область              да         0.60000002384186
# 10305  г. Москва и Московская область              да                   26.583
#
# [5 rows x 26 columns]

# %%
data.isna().sum()
# Out:
# Название                                 82
# Цена                                      0
# Дата                                      0
# Телефон                                   0
# Оператор                                  0
# Контактное лицо (автор объявления)       79
# Тип автора                                0
# Регион                                    0
# Город                                     0
# Метро/Район                            9329
# Адрес                                  3339
# Описание                                166
# Тип объявления                            0
# Категория1                                0
# Категория2                                0
# ID на сайте                               0
# Источник                                  0
# lat                                       0
# lng                                       0
# Персона для контактов                 20000
# Доп.параметры                             0
# URL                                       0
# Ссылки на картинки                      504
# Регион мобильного телефона                0
# Номер подменён                            0
# Расстояние до метро, км                   0
# dtype: int64

# %%
data = data.dropna(subset=["Цена"])

# %%
data.columns
# Out:
# Index(['Название', 'Цена', 'Дата', 'Телефон', 'Оператор',
#        'Контактное лицо (автор объявления)', 'Тип автора', 'Регион', 'Город',
#        'Метро/Район', 'Адрес', 'Описание', 'Тип объявления', 'Категория1',
#        'Категория2', 'ID на сайте', 'Источник', 'lat', 'lng',
#        'Персона для контактов', 'Доп.параметры', 'URL', 'Ссылки на картинки',
#        'Регион мобильного телефона', 'Номер подменён',
#        'Расстояние до метро, км'],
#       dtype='object')

# %%
data[['Тип объявления', 'Категория1', 'Категория2']].nunique()
# Out:
# Тип объявления    1
# Категория1        1
# Категория2        1
# dtype: int64

# %%
data = data.drop([
    'Телефон', 'Оператор', 'Контактное лицо (автор объявления)', 'Персона для контактов',
    'Номер подменён', 'Регион мобильного телефона', 'Регион',
    'Тип объявления', 'Категория1', 'Категория2',
], axis=1)

# %%
data.columns
# Out:
# Index(['Название', 'Цена', 'Дата', 'Тип автора', 'Город', 'Метро/Район',
#        'Адрес', 'Описание', 'ID на сайте', 'Источник', 'lat', 'lng',
#        'Доп.параметры', 'URL', 'Ссылки на картинки',
#        'Расстояние до метро, км'],
#       dtype='object')

# %%
data[['ID на сайте', 'Источник']]
# Out:
#                ID на сайте          Источник
# 19203            318640420           cian.ru
# 201              320032234           cian.ru
# 9441             319196407           cian.ru
# 13870           7444423554          avito.ru
# 10305            317908616           cian.ru
# ...                    ...               ...
# 4601             318638090           cian.ru
# 18906  6195427078783590726  realty.yandex.ru
# 7765             319584400           cian.ru
# 6216             318852438           cian.ru
# 14101            318723476           cian.ru
#
# [20000 rows x 2 columns]

# %%
data = data.set_index(['ID на сайте', 'Источник'])

# %%
data
# Out:
#                                                                                Название  \
# ID на сайте         Источник
# 318640420           cian.ru           Склад в Московская область, Мытищи городской о...
# 320032234           cian.ru           Помещение свободного назначения в Московская о...
# 319196407           cian.ru           Коммерческая земля в Московская область, Чехов...
# 7444423554          avito.ru                                Свободного назначения, 9 м²
# 317908616           cian.ru           Склад в Московская область, Раменский муниципа...
# ...                                                                                 ...
# 318638090           cian.ru           Склад в Московская область, Клин Волоколамское...
# 6195427078783590726 realty.yandex.ru                                      Офис (386 м²)
# 319584400           cian.ru           Склад в Московская область, Ногинск Богородски...
# 318852438           cian.ru           Склад в Московская область, Богородский городс...
# 318723476           cian.ru           Коммерческая земля в Московская область, Чехов...
#
#                                          Цена                 Дата Тип автора  \
# ID на сайте         Источник
# 318640420           cian.ru           1650000  2025-06-11 12:46:18  Агентство
# 320032234           cian.ru             35000  2025-07-30 08:23:45  Агентство
# 319196407           cian.ru             85493  2025-07-06 02:24:32  Агентство
# 7444423554          avito.ru            20700  2025-06-25 14:34:03  Агентство
# 317908616           cian.ru           2333300  2025-07-04 00:24:47  Агентство
# ...                                       ...                  ...        ...
# 318638090           cian.ru           9000000  2025-07-19 02:24:54  Агентство
# 6195427078783590726 realty.yandex.ru   482499  2025-06-13 00:05:48  Агентство
# 319584400           cian.ru           7453420  2025-07-09 16:25:08  Агентство
# 318852438           cian.ru            222600  2025-07-14 18:25:20  Агентство
# 318723476           cian.ru             61388  2025-06-25 02:36:47  Агентство
#
#                                                               Город  \
# ID на сайте         Источник
# 318640420           cian.ru                  Мытищи городской округ
# 320032234           cian.ru                                   Химки
# 319196407           cian.ru               Чехов муниципальный округ
# 7444423554          avito.ru                                Люберцы
# 317908616           cian.ru           Раменский муниципальный округ
# ...                                                             ...
# 318638090           cian.ru                                    Клин
# 6195427078783590726 realty.yandex.ru                          Химки
# 319584400           cian.ru                                 Ногинск
# 318852438           cian.ru             Богородский городской округ
# 318723476           cian.ru               Чехов муниципальный округ
#
#                                           Метро/Район  \
# ID на сайте         Источник
# 318640420           cian.ru                     Лобня
# 320032234           cian.ru               Беломорская
# 319196407           cian.ru                       NaN
# 7444423554          avito.ru               Котельники
# 317908616           cian.ru                 Раменское
# ...                                               ...
# 318638090           cian.ru                       NaN
# 6195427078783590726 realty.yandex.ru        Планерная
# 319584400           cian.ru                       NaN
# 318852438           cian.ru           Железнодорожная
# 318723476           cian.ru                       NaN
#
#                                                                                   Адрес  \
# ID на сайте         Источник
# 318640420           cian.ru                                                         NaN
# 320032234           cian.ru                                           Рабочая ул., 2Ак5
# 319196407           cian.ru                                                         NaN
# 7444423554          avito.ru          Московская обл., Люберцы, ул. Лётчика Ларюшина...
# 317908616           cian.ru                                         ул. Центральная, 1В
# ...                                                                                 ...
# 318638090           cian.ru                                         Волоколамское ш., 4
# 6195427078783590726 realty.yandex.ru                              улица Панфилова, 19с1
# 319584400           cian.ru           Богородский городской округ, Ногинск-Технопарк...
# 318852438           cian.ru                                         ул. Центральная, 14
# 318723476           cian.ru                                                         NaN
#
#                                                                                Описание  \
# ID на сайте         Источник
# 318640420           cian.ru           Уникальный номер помещения - 9539-141. Аренда ...
# 320032234           cian.ru           Сдаётся просторное помещение свободного назнач...
# 319196407           cian.ru           Дата начала аукциона: 11.07.2025 09:00 Размер ...
# 7444423554          avito.ru          ЖК Жулебино парк. Летчика Ларюшина 6к1. Большо...
# 317908616           cian.ru           958442 . Склaдской комплeкс РФЗ в Раменскoм рa...
# ...                                                                                 ...
# 318638090           cian.ru           Услуги ответственного хранения. Уникальный ном...
# 6195427078783590726 realty.yandex.ru  ПЛАТИМ ВОЗНАГРАЖДЕНИЕ  1) Пишите или звоните. ...
# 319584400           cian.ru           От Собственника. Предлагаю в долгосрочную арен...
# 318852438           cian.ru           Арт. 77185944 Производственно-складское помеще...
# 318723476           cian.ru           Дата начала аукциона: 09.07.2025 09:00 Размер ...
#
#                                             lat        lng  \
# ID на сайте         Источник
# 318640420           cian.ru           56.023751  37.502022
# 320032234           cian.ru           55.908444  37.433409
# 319196407           cian.ru           55.146462  37.300215
# 7444423554          avito.ru          55.678056  37.865076
# 317908616           cian.ru           55.600979  38.462743
# ...                                         ...        ...
# 318638090           cian.ru           56.331204  36.678842
# 6195427078783590726 realty.yandex.ru  55.881490  37.432934
# 319584400           cian.ru           55.826969  38.394364
# 318852438           cian.ru           55.763918  38.234239
# 318723476           cian.ru           55.210033  37.574737
#
#                                                                           Доп.параметры  \
# ID на сайте         Источник
# 318640420           cian.ru           Этаж=1|Этажность здания=1|Тип объявления=Сдам|...
# 320032234           cian.ru           Этаж=3|Этажность здания=7|Тип объявления=Сдам|...
# 319196407           cian.ru           Ед. измерения площади=сот.|Категория=Сельхозна...
# 7444423554          avito.ru          Этаж=1|Тип объявления=Сдам|Вид объекта=Помещен...
# 317908616           cian.ru           Этаж=1|Этажность здания=1|Тип объявления=Сдам|...
# ...                                                                                 ...
# 318638090           cian.ru           Этаж=1|Этажность здания=1|Тип объявления=Сдам|...
# 6195427078783590726 realty.yandex.ru  Этаж=3|Этажность здания=17|Тип объявления=Сдам...
# 319584400           cian.ru           Этаж=1|Этажность здания=1|Тип объявления=Сдам|...
# 318852438           cian.ru           Этаж=1|Этажность здания=1|Тип объявления=Сдам|...
# 318723476           cian.ru           Ед. измерения площади=сот.|Категория=Сельхозна...
#
#                                                                                     URL  \
# ID на сайте         Источник
# 318640420           cian.ru               https://www.cian.ru/rent/commercial/318640420
# 320032234           cian.ru               https://www.cian.ru/rent/commercial/320032234
# 319196407           cian.ru               https://www.cian.ru/rent/commercial/319196407
# 7444423554          avito.ru          https://www.avito.ru/lyubertsy/kommercheskaya_...
# 317908616           cian.ru               https://www.cian.ru/rent/commercial/317908616
# ...                                                                                 ...
# 318638090           cian.ru               https://www.cian.ru/rent/commercial/318638090
# 6195427078783590726 realty.yandex.ru    https://realty.ya.ru/offer/6195427078783590726/
# 319584400           cian.ru               https://www.cian.ru/rent/commercial/319584400
# 318852438           cian.ru               https://www.cian.ru/rent/commercial/318852438
# 318723476           cian.ru               https://www.cian.ru/rent/commercial/318723476
#
#                                                                      Ссылки на картинки  \
# ID на сайте         Источник
# 318640420           cian.ru           https://images.cdn-cian.ru/images/2520883320-1...
# 320032234           cian.ru           https://images.cdn-cian.ru/images/nezhiloe-pom...
# 319196407           cian.ru           https://images.cdn-cian.ru/images/2543367737-1...
# 7444423554          avito.ru          https://80.img.avito.st/image/1/1._E03Ira5UKQB...
# 317908616           cian.ru           https://images.cdn-cian.ru/images/2499464006-1...
# ...                                                                                 ...
# 318638090           cian.ru           https://images.cdn-cian.ru/images/2520800606-1...
# 6195427078783590726 realty.yandex.ru  https://avatars.mds.yandex.net/get-realty-offe...
# 319584400           cian.ru           https://images.cdn-cian.ru/images/2555791993-1...
# 318852438           cian.ru           https://images.cdn-cian.ru/images/2528802544-1...
# 318723476           cian.ru           https://images.cdn-cian.ru/images/2524014771-1...
#
#                                      Расстояние до метро, км
# ID на сайте         Источник
# 318640420           cian.ru                              5.5
# 320032234           cian.ru                            9.167
# 319196407           cian.ru                       неизвестно
# 7444423554          avito.ru                0.60000002384186
# 317908616           cian.ru                           26.583
# ...                                                      ...
# 318638090           cian.ru                       неизвестно
# 6195427078783590726 realty.yandex.ru                  15.583
# 319584400           cian.ru                       неизвестно
# 318852438           cian.ru                               22
# 318723476           cian.ru                       неизвестно
#
# [20000 rows x 14 columns]

# %%
# data.loc[(313517556, "cian.ru")]

# %%
data[["Название", "Описание"]]
# Out:
#                                                                                Название  \
# ID на сайте         Источник
# 318640420           cian.ru           Склад в Московская область, Мытищи городской о...
# 320032234           cian.ru           Помещение свободного назначения в Московская о...
# 319196407           cian.ru           Коммерческая земля в Московская область, Чехов...
# 7444423554          avito.ru                                Свободного назначения, 9 м²
# 317908616           cian.ru           Склад в Московская область, Раменский муниципа...
# ...                                                                                 ...
# 318638090           cian.ru           Склад в Московская область, Клин Волоколамское...
# 6195427078783590726 realty.yandex.ru                                      Офис (386 м²)
# 319584400           cian.ru           Склад в Московская область, Ногинск Богородски...
# 318852438           cian.ru           Склад в Московская область, Богородский городс...
# 318723476           cian.ru           Коммерческая земля в Московская область, Чехов...
#
#                                                                                Описание
# ID на сайте         Источник
# 318640420           cian.ru           Уникальный номер помещения - 9539-141. Аренда ...
# 320032234           cian.ru           Сдаётся просторное помещение свободного назнач...
# 319196407           cian.ru           Дата начала аукциона: 11.07.2025 09:00 Размер ...
# 7444423554          avito.ru          ЖК Жулебино парк. Летчика Ларюшина 6к1. Большо...
# 317908616           cian.ru           958442 . Склaдской комплeкс РФЗ в Раменскoм рa...
# ...                                                                                 ...
# 318638090           cian.ru           Услуги ответственного хранения. Уникальный ном...
# 6195427078783590726 realty.yandex.ru  ПЛАТИМ ВОЗНАГРАЖДЕНИЕ  1) Пишите или звоните. ...
# 319584400           cian.ru           От Собственника. Предлагаю в долгосрочную арен...
# 318852438           cian.ru           Арт. 77185944 Производственно-складское помеще...
# 318723476           cian.ru           Дата начала аукциона: 09.07.2025 09:00 Размер ...
#
# [20000 rows x 2 columns]

# %%
data.loc[:, ["Название", "Описание"]]
# Out:
#                                                                                Название  \
# ID на сайте         Источник
# 318640420           cian.ru           Склад в Московская область, Мытищи городской о...
# 320032234           cian.ru           Помещение свободного назначения в Московская о...
# 319196407           cian.ru           Коммерческая земля в Московская область, Чехов...
# 7444423554          avito.ru                                Свободного назначения, 9 м²
# 317908616           cian.ru           Склад в Московская область, Раменский муниципа...
# ...                                                                                 ...
# 318638090           cian.ru           Склад в Московская область, Клин Волоколамское...
# 6195427078783590726 realty.yandex.ru                                      Офис (386 м²)
# 319584400           cian.ru           Склад в Московская область, Ногинск Богородски...
# 318852438           cian.ru           Склад в Московская область, Богородский городс...
# 318723476           cian.ru           Коммерческая земля в Московская область, Чехов...
#
#                                                                                Описание
# ID на сайте         Источник
# 318640420           cian.ru           Уникальный номер помещения - 9539-141. Аренда ...
# 320032234           cian.ru           Сдаётся просторное помещение свободного назнач...
# 319196407           cian.ru           Дата начала аукциона: 11.07.2025 09:00 Размер ...
# 7444423554          avito.ru          ЖК Жулебино парк. Летчика Ларюшина 6к1. Большо...
# 317908616           cian.ru           958442 . Склaдской комплeкс РФЗ в Раменскoм рa...
# ...                                                                                 ...
# 318638090           cian.ru           Услуги ответственного хранения. Уникальный ном...
# 6195427078783590726 realty.yandex.ru  ПЛАТИМ ВОЗНАГРАЖДЕНИЕ  1) Пишите или звоните. ...
# 319584400           cian.ru           От Собственника. Предлагаю в долгосрочную арен...
# 318852438           cian.ru           Арт. 77185944 Производственно-складское помеще...
# 318723476           cian.ru           Дата начала аукциона: 09.07.2025 09:00 Размер ...
#
# [20000 rows x 2 columns]

# %%
# data.loc[
#     (313517556, "cian.ru"),
#     "Описание",
# ]

# %%
data["Название"] = data["Название"].fillna("").astype(str)
data["Описание"] = data["Описание"].fillna("").astype(str)
data["Описание"] = "НАЗВАНИЕ: " + data["Название"] + "\n\n" + "ОПИСАНИЕ: " + data["Описание"]

# %%
# print(data.loc[
#     (313517556, "cian.ru"),
#     "Описание",
# ])

# %%
data = data.drop("Название", axis=1)

# %%
data["Доп.параметры"].iloc[10]
# Out:
# 'Ед. измерения площади=сот.|Категория=Промназначение|Тип объявления=Сдам|Вид объекта=Коммерческая земля|Общая площадь=56.92'

# %%
def parse_parameters(v):
    return dict(
        pair.split("=")
        for pair in v.split("|")
    )

parse_parameters(data["Доп.параметры"].iloc[10])
# Out:
# {'Ед. измерения площади': 'сот.',
#  'Категория': 'Промназначение',
#  'Тип объявления': 'Сдам',
#  'Вид объекта': 'Коммерческая земля',
#  'Общая площадь': '56.92'}

# %%
_ = data["Доп.параметры"].apply(parse_parameters)
params_parsed = pd.json_normalize(_)
params_parsed.index = data.index
params_parsed
# Out:
#                                      Этаж Этажность здания Тип объявления  \
# ID на сайте         Источник
# 318640420           cian.ru             1                1           Сдам
# 320032234           cian.ru             3                7           Сдам
# 319196407           cian.ru           NaN              NaN           Сдам
# 7444423554          avito.ru            1              NaN           Сдам
# 317908616           cian.ru             1                1           Сдам
# ...                                   ...              ...            ...
# 318638090           cian.ru             1                1           Сдам
# 6195427078783590726 realty.yandex.ru    3               17           Сдам
# 319584400           cian.ru             1                1           Сдам
# 318852438           cian.ru             1                1           Сдам
# 318723476           cian.ru           NaN              NaN           Сдам
#
#                                                           Вид объекта  \
# ID на сайте         Источник
# 318640420           cian.ru                       Складское помещение
# 320032234           cian.ru           Помещение свободного назначения
# 319196407           cian.ru                        Коммерческая земля
# 7444423554          avito.ru          Помещение свободного назначения
# 317908616           cian.ru                       Складское помещение
# ...                                                               ...
# 318638090           cian.ru                       Складское помещение
# 6195427078783590726 realty.yandex.ru                Офисное помещение
# 319584400           cian.ru                       Складское помещение
# 318852438           cian.ru                       Складское помещение
# 318723476           cian.ru                        Коммерческая земля
#
#                                      Общая площадь Ед. измерения площади  \
# ID на сайте         Источник
# 318640420           cian.ru                   1500                   NaN
# 320032234           cian.ru                    100                   NaN
# 319196407           cian.ru                  13.34                  сот.
# 7444423554          avito.ru                     9                   NaN
# 317908616           cian.ru                   3500                   NaN
# ...                                            ...                   ...
# 318638090           cian.ru                  10000                   NaN
# 6195427078783590726 realty.yandex.ru           386                   NaN
# 319584400           cian.ru                   5260                   NaN
# 318852438           cian.ru                    600                   NaN
# 318723476           cian.ru                   8.08                  сот.
#
#                                               Категория Класс здания
# ID на сайте         Источник
# 318640420           cian.ru                         NaN          NaN
# 320032234           cian.ru                         NaN          NaN
# 319196407           cian.ru           Сельхозназначение          NaN
# 7444423554          avito.ru                        NaN          NaN
# 317908616           cian.ru                         NaN          NaN
# ...                                                 ...          ...
# 318638090           cian.ru                         NaN          NaN
# 6195427078783590726 realty.yandex.ru                NaN          NaN
# 319584400           cian.ru                         NaN          NaN
# 318852438           cian.ru                         NaN          NaN
# 318723476           cian.ru           Сельхозназначение          NaN
#
# [20000 rows x 8 columns]

# %%
params_parsed.isna().sum() / params_parsed.shape[0] * 100
# Out:
# Этаж                     21.080
# Этажность здания         58.110
# Тип объявления            0.000
# Вид объекта               1.215
# Общая площадь             0.055
# Ед. измерения площади    80.455
# Категория                80.995
# Класс здания             92.535
# dtype: float64

# %%
params_parsed.nunique()
# Out:
# Этаж                       32
# Этажность здания           45
# Тип объявления              1
# Вид объекта                 8
# Общая площадь            3654
# Ед. измерения площади       2
# Категория                   3
# Класс здания                4
# dtype: int64

# %%
params_parsed["Ед. измерения площади"].unique()
# Out:
# array([nan, 'сот.', 'га.'], dtype=object)

# %%
params_parsed = params_parsed.drop(["Класс здания", "Тип объявления"], axis=1)

# %%
data = pd.concat(
    [
        data.drop("Доп.параметры", axis=1),
        params_parsed
    ],
    axis=1
)
data
# Out:
#                                          Цена                 Дата Тип автора  \
# ID на сайте         Источник
# 318640420           cian.ru           1650000  2025-06-11 12:46:18  Агентство
# 320032234           cian.ru             35000  2025-07-30 08:23:45  Агентство
# 319196407           cian.ru             85493  2025-07-06 02:24:32  Агентство
# 7444423554          avito.ru            20700  2025-06-25 14:34:03  Агентство
# 317908616           cian.ru           2333300  2025-07-04 00:24:47  Агентство
# ...                                       ...                  ...        ...
# 318638090           cian.ru           9000000  2025-07-19 02:24:54  Агентство
# 6195427078783590726 realty.yandex.ru   482499  2025-06-13 00:05:48  Агентство
# 319584400           cian.ru           7453420  2025-07-09 16:25:08  Агентство
# 318852438           cian.ru            222600  2025-07-14 18:25:20  Агентство
# 318723476           cian.ru             61388  2025-06-25 02:36:47  Агентство
#
#                                                               Город  \
# ID на сайте         Источник
# 318640420           cian.ru                  Мытищи городской округ
# 320032234           cian.ru                                   Химки
# 319196407           cian.ru               Чехов муниципальный округ
# 7444423554          avito.ru                                Люберцы
# 317908616           cian.ru           Раменский муниципальный округ
# ...                                                             ...
# 318638090           cian.ru                                    Клин
# 6195427078783590726 realty.yandex.ru                          Химки
# 319584400           cian.ru                                 Ногинск
# 318852438           cian.ru             Богородский городской округ
# 318723476           cian.ru               Чехов муниципальный округ
#
#                                           Метро/Район  \
# ID на сайте         Источник
# 318640420           cian.ru                     Лобня
# 320032234           cian.ru               Беломорская
# 319196407           cian.ru                       NaN
# 7444423554          avito.ru               Котельники
# 317908616           cian.ru                 Раменское
# ...                                               ...
# 318638090           cian.ru                       NaN
# 6195427078783590726 realty.yandex.ru        Планерная
# 319584400           cian.ru                       NaN
# 318852438           cian.ru           Железнодорожная
# 318723476           cian.ru                       NaN
#
#                                                                                   Адрес  \
# ID на сайте         Источник
# 318640420           cian.ru                                                         NaN
# 320032234           cian.ru                                           Рабочая ул., 2Ак5
# 319196407           cian.ru                                                         NaN
# 7444423554          avito.ru          Московская обл., Люберцы, ул. Лётчика Ларюшина...
# 317908616           cian.ru                                         ул. Центральная, 1В
# ...                                                                                 ...
# 318638090           cian.ru                                         Волоколамское ш., 4
# 6195427078783590726 realty.yandex.ru                              улица Панфилова, 19с1
# 319584400           cian.ru           Богородский городской округ, Ногинск-Технопарк...
# 318852438           cian.ru                                         ул. Центральная, 14
# 318723476           cian.ru                                                         NaN
#
#                                                                                Описание  \
# ID на сайте         Источник
# 318640420           cian.ru           НАЗВАНИЕ: Склад в Московская область, Мытищи г...
# 320032234           cian.ru           НАЗВАНИЕ: Помещение свободного назначения в Мо...
# 319196407           cian.ru           НАЗВАНИЕ: Коммерческая земля в Московская обла...
# 7444423554          avito.ru          НАЗВАНИЕ: Свободного назначения, 9 м²\n\nОПИСА...
# 317908616           cian.ru           НАЗВАНИЕ: Склад в Московская область, Раменски...
# ...                                                                                 ...
# 318638090           cian.ru           НАЗВАНИЕ: Склад в Московская область, Клин Вол...
# 6195427078783590726 realty.yandex.ru  НАЗВАНИЕ: Офис (386 м²)\n\nОПИСАНИЕ: ПЛАТИМ ВО...
# 319584400           cian.ru           НАЗВАНИЕ: Склад в Московская область, Ногинск ...
# 318852438           cian.ru           НАЗВАНИЕ: Склад в Московская область, Богородс...
# 318723476           cian.ru           НАЗВАНИЕ: Коммерческая земля в Московская обла...
#
#                                             lat        lng  \
# ID на сайте         Источник
# 318640420           cian.ru           56.023751  37.502022
# 320032234           cian.ru           55.908444  37.433409
# 319196407           cian.ru           55.146462  37.300215
# 7444423554          avito.ru          55.678056  37.865076
# 317908616           cian.ru           55.600979  38.462743
# ...                                         ...        ...
# 318638090           cian.ru           56.331204  36.678842
# 6195427078783590726 realty.yandex.ru  55.881490  37.432934
# 319584400           cian.ru           55.826969  38.394364
# 318852438           cian.ru           55.763918  38.234239
# 318723476           cian.ru           55.210033  37.574737
#
#                                                                                     URL  \
# ID на сайте         Источник
# 318640420           cian.ru               https://www.cian.ru/rent/commercial/318640420
# 320032234           cian.ru               https://www.cian.ru/rent/commercial/320032234
# 319196407           cian.ru               https://www.cian.ru/rent/commercial/319196407
# 7444423554          avito.ru          https://www.avito.ru/lyubertsy/kommercheskaya_...
# 317908616           cian.ru               https://www.cian.ru/rent/commercial/317908616
# ...                                                                                 ...
# 318638090           cian.ru               https://www.cian.ru/rent/commercial/318638090
# 6195427078783590726 realty.yandex.ru    https://realty.ya.ru/offer/6195427078783590726/
# 319584400           cian.ru               https://www.cian.ru/rent/commercial/319584400
# 318852438           cian.ru               https://www.cian.ru/rent/commercial/318852438
# 318723476           cian.ru               https://www.cian.ru/rent/commercial/318723476
#
#                                                                      Ссылки на картинки  \
# ID на сайте         Источник
# 318640420           cian.ru           https://images.cdn-cian.ru/images/2520883320-1...
# 320032234           cian.ru           https://images.cdn-cian.ru/images/nezhiloe-pom...
# 319196407           cian.ru           https://images.cdn-cian.ru/images/2543367737-1...
# 7444423554          avito.ru          https://80.img.avito.st/image/1/1._E03Ira5UKQB...
# 317908616           cian.ru           https://images.cdn-cian.ru/images/2499464006-1...
# ...                                                                                 ...
# 318638090           cian.ru           https://images.cdn-cian.ru/images/2520800606-1...
# 6195427078783590726 realty.yandex.ru  https://avatars.mds.yandex.net/get-realty-offe...
# 319584400           cian.ru           https://images.cdn-cian.ru/images/2555791993-1...
# 318852438           cian.ru           https://images.cdn-cian.ru/images/2528802544-1...
# 318723476           cian.ru           https://images.cdn-cian.ru/images/2524014771-1...
#
#                                      Расстояние до метро, км Этаж  \
# ID на сайте         Источник
# 318640420           cian.ru                              5.5    1
# 320032234           cian.ru                            9.167    3
# 319196407           cian.ru                       неизвестно  NaN
# 7444423554          avito.ru                0.60000002384186    1
# 317908616           cian.ru                           26.583    1
# ...                                                      ...  ...
# 318638090           cian.ru                       неизвестно    1
# 6195427078783590726 realty.yandex.ru                  15.583    3
# 319584400           cian.ru                       неизвестно    1
# 318852438           cian.ru                               22    1
# 318723476           cian.ru                       неизвестно  NaN
#
#                                      Этажность здания  \
# ID на сайте         Источник
# 318640420           cian.ru                         1
# 320032234           cian.ru                         7
# 319196407           cian.ru                       NaN
# 7444423554          avito.ru                      NaN
# 317908616           cian.ru                         1
# ...                                               ...
# 318638090           cian.ru                         1
# 6195427078783590726 realty.yandex.ru               17
# 319584400           cian.ru                         1
# 318852438           cian.ru                         1
# 318723476           cian.ru                       NaN
#
#                                                           Вид объекта  \
# ID на сайте         Источник
# 318640420           cian.ru                       Складское помещение
# 320032234           cian.ru           Помещение свободного назначения
# 319196407           cian.ru                        Коммерческая земля
# 7444423554          avito.ru          Помещение свободного назначения
# 317908616           cian.ru                       Складское помещение
# ...                                                               ...
# 318638090           cian.ru                       Складское помещение
# 6195427078783590726 realty.yandex.ru                Офисное помещение
# 319584400           cian.ru                       Складское помещение
# 318852438           cian.ru                       Складское помещение
# 318723476           cian.ru                        Коммерческая земля
#
#                                      Общая площадь Ед. измерения площади  \
# ID на сайте         Источник
# 318640420           cian.ru                   1500                   NaN
# 320032234           cian.ru                    100                   NaN
# 319196407           cian.ru                  13.34                  сот.
# 7444423554          avito.ru                     9                   NaN
# 317908616           cian.ru                   3500                   NaN
# ...                                            ...                   ...
# 318638090           cian.ru                  10000                   NaN
# 6195427078783590726 realty.yandex.ru           386                   NaN
# 319584400           cian.ru                   5260                   NaN
# 318852438           cian.ru                    600                   NaN
# 318723476           cian.ru                   8.08                  сот.
#
#                                               Категория
# ID на сайте         Источник
# 318640420           cian.ru                         NaN
# 320032234           cian.ru                         NaN
# 319196407           cian.ru           Сельхозназначение
# 7444423554          avito.ru                        NaN
# 317908616           cian.ru                         NaN
# ...                                                 ...
# 318638090           cian.ru                         NaN
# 6195427078783590726 realty.yandex.ru                NaN
# 319584400           cian.ru                         NaN
# 318852438           cian.ru                         NaN
# 318723476           cian.ru           Сельхозназначение
#
# [20000 rows x 18 columns]

# %%
data.dtypes
# Out:
# Цена                         int64
# Дата                        object
# Тип автора                  object
# Город                       object
# Метро/Район                 object
# Адрес                       object
# Описание                    object
# lat                        float64
# lng                        float64
# URL                         object
# Ссылки на картинки          object
# Расстояние до метро, км     object
# Этаж                        object
# Этажность здания            object
# Вид объекта                 object
# Общая площадь               object
# Ед. измерения площади       object
# Категория                   object
# dtype: object

# %%
data["Категория"].unique()
# Out:
# array([nan, 'Сельхозназначение', 'Участок поселений', 'Промназначение'],
#       dtype=object)

# %%
data["Дата"] = pd.to_datetime(data["Дата"])
data["Дата"]
# Out:
# ID на сайте          Источник
# 318640420            cian.ru            2025-06-11 12:46:18
# 320032234            cian.ru            2025-07-30 08:23:45
# 319196407            cian.ru            2025-07-06 02:24:32
# 7444423554           avito.ru           2025-06-25 14:34:03
# 317908616            cian.ru            2025-07-04 00:24:47
#                                                 ...
# 318638090            cian.ru            2025-07-19 02:24:54
# 6195427078783590726  realty.yandex.ru   2025-06-13 00:05:48
# 319584400            cian.ru            2025-07-09 16:25:08
# 318852438            cian.ru            2025-07-14 18:25:20
# 318723476            cian.ru            2025-06-25 02:36:47
# Name: Дата, Length: 20000, dtype: datetime64[ns]

# %%
data["Дата"].dt.dayofyear
# Out:
# ID на сайте          Источник
# 318640420            cian.ru             162
# 320032234            cian.ru             211
# 319196407            cian.ru             187
# 7444423554           avito.ru            176
# 317908616            cian.ru             185
#                                         ...
# 318638090            cian.ru             200
# 6195427078783590726  realty.yandex.ru    164
# 319584400            cian.ru             190
# 318852438            cian.ru             195
# 318723476            cian.ru             176
# Name: Дата, Length: 20000, dtype: int32

# %%
# data[[
#     "Расстояние до метро, км",
#     "Этаж",
#     "Общая площадь",
#     "Этажность здания",
# ]].astype(float)

# %%
data["Расстояние до метро, км"]
# Out:
# ID на сайте          Источник
# 318640420            cian.ru                          5.5
# 320032234            cian.ru                        9.167
# 319196407            cian.ru                   неизвестно
# 7444423554           avito.ru            0.60000002384186
# 317908616            cian.ru                       26.583
#                                                ...
# 318638090            cian.ru                   неизвестно
# 6195427078783590726  realty.yandex.ru              15.583
# 319584400            cian.ru                   неизвестно
# 318852438            cian.ru                           22
# 318723476            cian.ru                   неизвестно
# Name: Расстояние до метро, км, Length: 20000, dtype: object

# %%
data["Расстояние до метро, км"] = data["Расстояние до метро, км"].replace({"неизвестно": np.nan}).values

# %%
data[[
    "Расстояние до метро, км",
    "Этаж",
    "Общая площадь",
    "Этажность здания",
]] = data[[
    "Расстояние до метро, км",
    "Этаж",
    "Общая площадь",
    "Этажность здания",
]].astype(float)

# %%
data.isna().sum()
# Out:
# Цена                           0
# Дата                           0
# Тип автора                     0
# Город                          0
# Метро/Район                 9329
# Адрес                       3339
# Описание                       0
# lat                            0
# lng                            0
# URL                            0
# Ссылки на картинки           504
# Расстояние до метро, км    10304
# Этаж                        4216
# Этажность здания           11622
# Вид объекта                  243
# Общая площадь                 11
# Ед. измерения площади      16091
# Категория                  16199
# dtype: int64

# %%
data["Ед. измерения площади"].value_counts()
# Out:
# Ед. измерения площади
# сот.    3858
# га.       51
# Name: count, dtype: int64

# %%
data.dropna(subset=["Общая площадь", "Ед. измерения площади"])[["Общая площадь", "Ед. измерения площади"]]
# Out:
#                       Общая площадь Ед. измерения площади
# ID на сайте Источник
# 319196407   cian.ru           13.34                  сот.
# 319487008   cian.ru           14.00                  сот.
# 319366775   cian.ru           30.00                  сот.
# 318706285   cian.ru           20.93                  сот.
# 319557276   cian.ru           56.92                  сот.
# ...                             ...                   ...
# 319148778   cian.ru            2.30                  сот.
# 318871793   cian.ru           10.22                  сот.
# 318313209   cian.ru           61.52                  сот.
# 319153422   cian.ru            7.97                  сот.
# 318723476   cian.ru            8.08                  сот.
#
# [3909 rows x 2 columns]

# %%
data[["Общая площадь", "Ед. измерения площади"]].dropna()
# Out:
#                       Общая площадь Ед. измерения площади
# ID на сайте Источник
# 319196407   cian.ru           13.34                  сот.
# 319487008   cian.ru           14.00                  сот.
# 319366775   cian.ru           30.00                  сот.
# 318706285   cian.ru           20.93                  сот.
# 319557276   cian.ru           56.92                  сот.
# ...                             ...                   ...
# 319148778   cian.ru            2.30                  сот.
# 318871793   cian.ru           10.22                  сот.
# 318313209   cian.ru           61.52                  сот.
# 319153422   cian.ru            7.97                  сот.
# 318723476   cian.ru            8.08                  сот.
#
# [3909 rows x 2 columns]

# %%
data[["Общая площадь", "Ед. измерения площади"]].sample(5)
# Out:
#                       Общая площадь Ед. измерения площади
# ID на сайте Источник
# 7575564995  avito.ru          56.60                   NaN
# 7565199873  avito.ru         316.30                   NaN
# 318974130   cian.ru           14.18                  сот.
# 316223623   cian.ru           12.08                  сот.
# 319074136   cian.ru           16.27                  сот.

# %%
data.loc[
    data["Ед. измерения площади"] == "сот.",
    "Общая площадь"
] *= 100

data.loc[
    data["Ед. измерения площади"] == "га.",
    "Общая площадь"
] *= 10000

# %%
data = data.drop("Ед. измерения площади", axis=1)

# %%
data.to_csv("../data/data_transformed_part3.csv")
